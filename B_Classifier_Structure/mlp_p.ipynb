# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.utils.data as Data
from torchmetrics import Accuracy, Precision, Recall, F1Score, AUROC
import numpy as np
import h5py

from utils import EarlyStopping

# %%
# Initialize metrics
task = "binary"
accuracy = Accuracy(task)
precision = Precision(task)
recall = Recall(task)
f1_score = F1Score(task)
auroc = AUROC(task)

# %%
# Hyperparameters and constants
lr= 0.008953 #1E-2

batch_size = 32
epochs = 100   # define number of training epochs

# Data
frac_train = 0.7
frac_val = 0.10
frac_test = 0.20
# LR scheduler
step_size=20 # 10
gamma=0.8285 # 0.7

# %%
# Define your loss function here
class Lossfunc(object):
    def __init__(self):
        self.loss = nn.BCELoss()
    def __call__(self, pred, target):
        return self.loss(pred, target)
    
# This reads the matlab data from the .mat file provided
# This reads the matlab data from the .mat file provided
class MatRead(object):
    def __init__(self, file_path):
        super(MatRead).__init__()
        self.file_path = file_path
        self.data = h5py.File(self.file_path)

    def get_load_apply(self):
        return torch.tensor(np.array(self.data['load_apply']).transpose(1,0), dtype=torch.float32)

    def get_result(self):
        return torch.tensor(np.array(self.data['result']).transpose(1,0), dtype=torch.float32)

# %%
######################### Data processing #############################
# Read data from .mat file
path = 'Data/Eiffel_data.mat' #Define your data path here
data_reader = MatRead(path)
x = data_reader.get_load_apply()
y = data_reader.get_result()

# %%
print(f"Feature is x.shape={x.shape}, Label is y.shape={y.shape}")
# Out:
# Feature is x.shape=torch.Size([1000, 20]), Label is y.shape=torch.Size([1000, 1])

# %%
x.isnan().sum().item(), y.isnan().sum().item()
# Out:
# (0, 0)

# %%
# Split the data into training and testing sets
ntrain = int(frac_train * x.shape[0])
nval = int(frac_val * x.shape[0])
ntest = x.shape[0] - ntrain - nval
x_train = x[:ntrain, ...]
y_train = y[:ntrain, ...]
x_val = x[ntrain:ntrain+nval, ...]
y_val = y[ntrain:ntrain+nval, ...]
x_test = x[ntrain+nval:, ...]
y_test = y[ntrain+nval:, ...]
ntrain,nval,ntest
# Out:
# (700, 100, 200)

# %%
# Define data normalizer
class DataNormalizer(object):
    """
    Input shape: (dataset_size, time_steps, 6) where 6 is the number of strain/ stress components (exx, eyy, ezz, exy, eyz, ezx).
    Normalize the strain/stress data to have range 0,1.
    """
    def __init__(self, data, epsilon=1e-4):
        self.epsilon = epsilon
        # Compute min and max across dataset_size and time_steps
        self.min = torch.amin(data, dim=0, keepdim=True)
        self.max = torch.amax(data, dim=0, keepdim=True)
        
        self.range = self.max - self.min
        # Prevent zero-range issues
        self.range = torch.where(self.range > self.epsilon, self.range, torch.tensor(1.0))
        
    @torch.no_grad()
    def normalize(self, data):
        return (data - self.min) / self.range

    def denormalize(self, data):
        return data * self.range + self.min
        
# Define data normalizer
class DataStandardizer(object):
    """
    Input shape: (dataset_size, time_steps, 6) where 6 is the number of strain/ stress components (exx, eyy, ezz, exy, eyz, ezx).
    Normalize the strain/stress data to have range 0,1.
    """
    def __init__(self, data, epsilon=1e-6):
        self.epsilon = epsilon
        # Compute mean and std across dataset_size and time_steps
        self.mean = torch.mean(data, dim=0)
        self.std = torch.std(data, dim=0)#+self.epsilon
        
    @torch.no_grad()
    def normalize(self, data):
        return (data - self.mean) / (self.std + self.epsilon)

    def denormalize(self, data):
        return data * self.std + self.mean

# %%
# Normalize your data
x_normalizer   = DataStandardizer(x_train)
x_train_encode = x_normalizer.normalize(x_train)
x_val_encode   = x_normalizer.normalize(x_val)
x_test_encode  = x_normalizer.normalize(x_test)

# %%
# Visualize a hisogram of the normalized data
plt.figure(1)
for i in range(20):
    plt.subplot(4, 5,i+1)
    plt.hist(x_train_encode[:,i].flatten().numpy(), bins=10, alpha=0.5, label='x_train')
    plt.hist(x_val_encode[:,i].flatten().numpy(), bins=10, alpha=0.5, label='x_val')
    plt.hist(x_test_encode[:,i].flatten().numpy(), bins=10, alpha=0.5, label='x_test')
    plt.grid()
    #plt.xlabel('Normalized Load')
    #plt.ylabel('Frequency')
#plt.legend()

# %%
ndim = x.shape[1]  # Number of components
ndim
# Out:
# 20

# %%
# Create data loader
train_set = Data.TensorDataset(x_train_encode, y_train)
val_set = Data.TensorDataset(x_val_encode, y_val)
test_set = Data.TensorDataset(x_test_encode, y_test)
train_loader = Data.DataLoader(train_set, batch_size, shuffle=True)
val_loader = Data.DataLoader(val_set, batch_size, shuffle=False)
test_loader = Data.DataLoader(test_set, batch_size, shuffle=False)

# %%
#Define and train network
class Const_Net(nn.Module):
    def __init__(self):
        super(Const_Net, self).__init__()
        self.fc1 = nn.Linear(ndim, 1000)
        self.fc2 = nn.Linear(1000, 500)
        self.fc3 = nn.Linear(500, 50)#5
        self.fc4 = nn.Linear(50, 1) #5
        
        self.batchnorm1 = nn.BatchNorm1d(1000)
        self.batchnorm2 = nn.BatchNorm1d(500)
        self.batchnorm3 = nn.BatchNorm1d(50)
        self.dropout = nn.Dropout(0.1)
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.batchnorm1(x)
        x = self.dropout(x)
        x = torch.relu(self.fc2(x))
        x = self.batchnorm2(x)
        x = self.dropout(x)
        x = torch.relu(self.fc3(x))
        x = self.batchnorm3(x)
        x = self.fc4(x)
        x = torch.sigmoid(x)
        return x

net = Const_Net()
n_params = sum(p.numel() for p in net.parameters() if p.requires_grad) #Calculate the number of training parameters
print('Number of parameters: %d' % n_params)
# Out:
# Number of parameters: 549701

# %%
loss_func = Lossfunc() #define loss function
optimizer = torch.optim.Adam(net.parameters(), lr=lr) #define optimizer
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size,gamma=gamma) #define learning rate scheduler
early_stopping = EarlyStopping(patience=80, min_delta=0.0005)

# %%
# Train network
loss_train_list = []
loss_val_list = []

acc_train_list = []
acc_val_list = []

prec_train_list = []
prec_val_list = []

rec_train_list = []
rec_val_list = []

f1_train_list = []
f1_val_list = []

auc_train_list = []
auc_val_list = []

# %%
print("Start training for {} epochs...".format(epochs))

for epoch in range(epochs):
    net.train(True)
    
    outputs_train = []
    outputs_val = []
    targets_train_list = []
    train_loss = 0.

    for i, data in enumerate(train_loader):
        optimizer.zero_grad()
        input, target = data
        #define forward neural network evaluation below
        output = net(input)
        #cache the outputs along axis 0 to compute metrics
        loss = loss_func(output, target)
        loss.backward()
        optimizer.step()
        scheduler.step()
        train_loss += loss.item()
        outputs_train.append(output.detach().cpu())
        targets_train_list.append(target.detach().cpu())
        
    outputs_train = torch.cat(outputs_train, dim=0)
    targets_train = torch.cat(targets_train_list, dim=0)
    
    # Compute train metrics per epoch
    train_loss = round(train_loss/len(train_loader),5)
    loss_train_list.append(round(train_loss,3))
    acc_train_list.append(round(accuracy(outputs_train, targets_train).item(),3))
    prec_train_list.append(round(precision(outputs_train, targets_train).item(),3))
    rec_train_list.append(round(recall(outputs_train, targets_train).item(),3))
    f1_train_list.append(round(f1_score(outputs_train, targets_train).item(),3))
    auc_train_list.append(round(auroc(outputs_train, targets_train).item(),3))

    # Compute your val loss below
    net.eval()
    val_loss = 0.
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            input, target = data
            output = net(input)
            outputs_val.append(output)
            loss = loss_func(output, target)
            val_loss += loss.item()
             
    outputs_val = torch.cat(outputs_val, dim=0)
    # Compute val metrics per epoch
    val_loss = round(val_loss/len(val_loader),5)
    loss_val_list.append(val_loss)
    acc_val_list.append(round(accuracy(outputs_val, y_val).item(),3))
    prec_val_list.append(round(precision(outputs_val, y_val).item(),3))
    rec_val_list.append(round(recall(outputs_val, y_val).item(),3))
    f1_val_list.append(round(f1_score(outputs_val, y_val).item(),3))
    auc_val_list.append(round(auroc(outputs_val, y_val).item(),3))
    
    # Print train loss every 10 epochs
    if (epoch % 10 == 0):
        print("epoch:{}, train loss:{}, val loss:{}, train acc:{}, val acc:{}".format(epoch, train_loss, val_loss, acc_train_list[-1], acc_val_list[-1]))
    
    # Check early stopping
    early_stopping(val_loss)
    if early_stopping.early_stop:
        break  # Stop training if triggered

print("Training complete!")

print(f"""
FINAL TRAIN METRICS: 
loss={loss_train_list[-1]},
acc={acc_train_list[-1]}, 
prec={prec_train_list[-1]}, 
rec={rec_train_list[-1]}, 
f1={f1_train_list[-1]}, 
auroc={auc_train_list[-1]}
____________________________________________________
""")

print(f"""
Final VAL METRICS:
loss={loss_val_list[-1]},
acc={acc_val_list[-1]}, 
prec={prec_val_list[-1]}, 
rec={rec_val_list[-1]}, 
f1={f1_val_list[-1]}, 
auroc={auc_val_list[-1]}
____________________________________________________
""")

torch.save(net.state_dict(), 'mlp_model_p.pth')
# Out:
# Start training for 100 epochs...
# epoch:0, train loss:0.18316, val loss:0.12693, train acc:0.933, val acc:0.92
# epoch:10, train loss:0.10382, val loss:0.04782, train acc:0.97, val acc:0.98
# epoch:20, train loss:0.0998, val loss:0.05059, train acc:0.964, val acc:0.98
# epoch:30, train loss:0.08524, val loss:0.05547, train acc:0.969, val acc:0.98
# epoch:40, train loss:0.07323, val loss:0.04951, train acc:0.973, val acc:0.98
# epoch:50, train loss:0.055, val loss:0.05105, train acc:0.974, val acc:0.98
# epoch:60, train loss:0.07171, val loss:0.04909, train acc:0.973, val acc:0.98
# epoch:70, train loss:0.05689, val loss:0.04903, train acc:0.976, val acc:0.98
# epoch:80, train loss:0.08098, val loss:0.05223, train acc:0.967, val acc:0.98
# epoch:90, train loss:0.05317, val loss:0.04817, train acc:0.981, val acc:0.98
# Training complete!
#
# FINAL TRAIN METRICS:
# loss=0.055,
# acc=0.977,
# prec=0.975,
# rec=0.968,
# f1=0.971,
# auroc=0.998
# ____________________________________________________
#
#
# Final VAL METRICS:
# loss=0.04931,
# acc=0.98,
# prec=0.974,
# rec=0.974,
# f1=0.974,
# auroc=0.998
# ____________________________________________________

# %%
#save the loss_train_list values for plotting
from numpy import save as np_save 
np_save('task_a_lstm_loss_train.npy', loss_train_list)

# %%
############################# Plot your result below using Matplotlib #############################
plt.figure(1)
plt.plot(loss_train_list, label='Train Loss')
plt.plot(loss_val_list, label='Val Loss')
plt.legend()
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train and Val Losses')
plt.savefig("task_b_mlp_loss.png")

# %%
############################# Plot your result below using Matplotlib #############################
plt.figure(1)
plt.plot(acc_train_list, label='Train Accuracy')
plt.plot(acc_val_list, label='Validation Accuracy')
plt.legend()
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train and Val Accuracy')
plt.savefig("task_b_mlp_acc.png")

# %%
############################# Plot your result below using Matplotlib #############################
plt.figure(1)
plt.plot(acc_train_list, label='Train F1')
plt.plot(acc_val_list, label='Val F1')
plt.legend()
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('F1-Score')
plt.title('Train and Val F1-Score')
plt.savefig("task_b_mlp_f1.png")

# %%
############################# Plot your result below using Matplotlib #############################
plt.figure(1)
plt.plot(prec_train_list, label='Train precision')
plt.plot(prec_val_list, label='Val precision')
plt.legend()
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Train and Val Precision')
plt.savefig("task_b_mlp_prec.png")

# %%
############################# Plot your result below using Matplotlib #############################
plt.figure(1)
plt.plot(rec_train_list, label='Train recall')
plt.plot(rec_val_list, label='Val recall')
plt.legend()
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Train and Val Recall')
plt.savefig("task_b_mlp_recall.png")

# %%
############################# Plot your result below using Matplotlib #############################
plt.figure(1)
plt.plot(rec_train_list, label='Train AUROC')
plt.plot(rec_val_list, label='Val AUROC')
plt.legend()
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('AUROC')
plt.title('Train and Val AUROC')
plt.savefig("task_b_mlp_auroc.png")

# %%
# Compute your TEST loss below
net.eval()
test_loss = 0.
outputs_test = []
loss_test = None
acc_test = None
prec_test = None
rec_test = None
f1_test = None
auc_test = None
with torch.no_grad():
    for i, data in enumerate(test_loader):
        input, target = data
        output = net(input)
        outputs_test.append(output)
        loss = loss_func(output, target)
        test_loss += loss.item()
         
outputs_test = torch.cat(outputs_test, dim=0)
# Compute val metrics per epoch
loss_test = round(test_loss/len(test_loader),5)     
acc_test=round(accuracy(outputs_test, y_test).item(),3)
prec_test=round(precision(outputs_test, y_test).item(),3)
rec_test=round(recall(outputs_test, y_test).item(),3)
f1_test=round(f1_score(outputs_test, y_test).item(),3)
auc_test=round(auroc(outputs_test, y_test).item(),3)

print(f"""
FINAL TEST METRICS:
loss={loss_test},
acc={acc_test},
prec={prec_test},
rec={rec_test},
f1={f1_test},
auroc={auc_test}
____________________________________________________
""")
# Out:
# FINAL TEST METRICS:
# loss=0.06589,
# acc=0.965,
# prec=1.0,
# rec=0.918,
# f1=0.957,
# auroc=0.999
# ____________________________________________________

# %% [markdown]
# ### Hyperparameter Optimization (Bayesian/Genetic Algorithm for online pruning of search space)

# %%
# Advanced optimization
% conda install optuna

# %%
import optuna

def objective_train(trial):
    # Sample training hyperparameters
    lr = trial.suggest_loguniform('lr', 1e-4, 1)
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])
    step_size = trial.suggest_int('step_size', 5, 20)
    gamma = trial.suggest_float('gamma', 0.1, 0.9)
    
    # Create DataLoaders
    train_set = Data.TensorDataset(x_train_encode, y_train)
    val_set   = Data.TensorDataset(x_val_encode, y_val)
    train_loader = Data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
    val_loader   = Data.DataLoader(val_set, batch_size=batch_size, shuffle=False)
    
    # Build fixed architecture network
    net = Const_Net()
    loss_func = Lossfunc()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
    
    num_epochs = 50  # fewer epochs for faster hyperparameter search
    best_val_loss = float('inf')
    for epoch in range(num_epochs):
        net.train()
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = loss_func(outputs, targets)
            loss.backward()
            optimizer.step()
            scheduler.step()
        
        net.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                outputs = net(inputs)
                loss = loss_func(outputs, targets)
                val_loss += loss.item()
        val_loss /= len(val_loader)
        
        trial.report(val_loss, epoch)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            
    return best_val_loss

# Run Stage 1 optimization
study_train = optuna.create_study(direction="minimize")
study_train.optimize(objective_train, n_trials=1_000)
print("Stage 1 (Training hyperparameters) Best trial:")
for key, value in study_train.best_trial.params.items():
    print(f"  {key}: {value}")

best_train_params = study_train.best_trial.params
# Out:
# [I 2025-02-25 16:27:28,746] A new study created in memory with name: no-name-d39a6fb4-1ede-4548-a558-559dbb51fe01
# /tmp/ipykernel_871088/1359135622.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-4, 1)
# [I 2025-02-25 16:27:34,610] Trial 0 finished with value: 0.042676265409681946 and parameters: {'lr': 0.010715466974740812, 'batch_size': 32, 'step_size': 18, 'gamma': 0.7143230707838119}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:27:37,671] Trial 1 finished with value: 0.05155682936310768 and parameters: {'lr': 0.0982125726692183, 'batch_size': 64, 'step_size': 18, 'gamma': 0.7377737555771761}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:27:42,686] Trial 2 finished with value: 0.23092917539179325 and parameters: {'lr': 0.00011306224486217671, 'batch_size': 32, 'step_size': 8, 'gamma': 0.34998547078354153}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:27:48,738] Trial 3 finished with value: 0.10030700592324138 and parameters: {'lr': 0.02449035163828991, 'batch_size': 32, 'step_size': 7, 'gamma': 0.3273055779297098}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:27:53,248] Trial 4 finished with value: 0.17357668280601501 and parameters: {'lr': 0.002109030727951608, 'batch_size': 64, 'step_size': 9, 'gamma': 0.20239903476739923}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:27:53,322] Trial 5 pruned.
# [I 2025-02-25 16:27:53,443] Trial 6 pruned.
# [I 2025-02-25 16:28:05,595] Trial 7 finished with value: 0.0667259580917354 and parameters: {'lr': 0.36907213498164815, 'batch_size': 16, 'step_size': 14, 'gamma': 0.23127596194711295}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:05,707] Trial 8 pruned.
# [I 2025-02-25 16:28:05,954] Trial 9 pruned.
# [I 2025-02-25 16:28:09,329] Trial 10 finished with value: 0.057288678362965584 and parameters: {'lr': 0.00174390282494844, 'batch_size': 32, 'step_size': 20, 'gamma': 0.7139429429168481}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:09,402] Trial 11 pruned.
# [I 2025-02-25 16:28:09,460] Trial 12 pruned.
# [I 2025-02-25 16:28:09,534] Trial 13 pruned.
# [I 2025-02-25 16:28:09,698] Trial 14 pruned.
# [I 2025-02-25 16:28:09,805] Trial 15 pruned.
# [I 2025-02-25 16:28:09,872] Trial 16 pruned.
# [I 2025-02-25 16:28:09,936] Trial 17 pruned.
# [I 2025-02-25 16:28:10,032] Trial 18 pruned.
# [I 2025-02-25 16:28:10,230] Trial 19 pruned.
# [I 2025-02-25 16:28:10,321] Trial 20 pruned.
# [I 2025-02-25 16:28:13,832] Trial 21 finished with value: 0.060437464620918036 and parameters: {'lr': 0.0023036092126339034, 'batch_size': 32, 'step_size': 20, 'gamma': 0.6760178869183228}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:13,920] Trial 22 pruned.
# [I 2025-02-25 16:28:14,446] Trial 23 pruned.
# [I 2025-02-25 16:28:18,820] Trial 24 finished with value: 0.05021449876949191 and parameters: {'lr': 0.00466601153077869, 'batch_size': 32, 'step_size': 20, 'gamma': 0.6399236353439876}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:18,892] Trial 25 pruned.
# [I 2025-02-25 16:28:18,997] Trial 26 pruned.
# [I 2025-02-25 16:28:19,079] Trial 27 pruned.
# [I 2025-02-25 16:28:19,223] Trial 28 pruned.
# [I 2025-02-25 16:28:19,303] Trial 29 pruned.
# [I 2025-02-25 16:28:22,793] Trial 30 finished with value: 0.048864307813346386 and parameters: {'lr': 0.0035913583201678955, 'batch_size': 32, 'step_size': 11, 'gamma': 0.835997273848833}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:22,960] Trial 31 pruned.
# [I 2025-02-25 16:28:23,049] Trial 32 pruned.
# [I 2025-02-25 16:28:23,142] Trial 33 pruned.
# [I 2025-02-25 16:28:23,228] Trial 34 pruned.
# [I 2025-02-25 16:28:26,661] Trial 35 finished with value: 0.05642442381940782 and parameters: {'lr': 0.010410811226611647, 'batch_size': 32, 'step_size': 11, 'gamma': 0.7543395384907218}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:26,733] Trial 36 pruned.
# [I 2025-02-25 16:28:30,597] Trial 37 finished with value: 0.047193839243846014 and parameters: {'lr': 0.23307510299926404, 'batch_size': 32, 'step_size': 14, 'gamma': 0.46058149977294005}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:30,686] Trial 38 pruned.
# [I 2025-02-25 16:28:30,776] Trial 39 pruned.
# [I 2025-02-25 16:28:30,880] Trial 40 pruned.
# [I 2025-02-25 16:28:30,974] Trial 41 pruned.
# [I 2025-02-25 16:28:31,058] Trial 42 pruned.
# [I 2025-02-25 16:28:31,219] Trial 43 pruned.
# [I 2025-02-25 16:28:31,291] Trial 44 pruned.
# [I 2025-02-25 16:28:31,390] Trial 45 pruned.
# [I 2025-02-25 16:28:31,510] Trial 46 pruned.
# [I 2025-02-25 16:28:31,569] Trial 47 pruned.
# [I 2025-02-25 16:28:31,669] Trial 48 pruned.
# [I 2025-02-25 16:28:31,836] Trial 49 pruned.
# [I 2025-02-25 16:28:31,902] Trial 50 pruned.
# [I 2025-02-25 16:28:32,065] Trial 51 pruned.
# [I 2025-02-25 16:28:32,163] Trial 52 pruned.
# [I 2025-02-25 16:28:32,261] Trial 53 pruned.
# [I 2025-02-25 16:28:35,803] Trial 54 finished with value: 0.05620080744847655 and parameters: {'lr': 0.0023912704024262304, 'batch_size': 32, 'step_size': 9, 'gamma': 0.8454524206709981}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:35,990] Trial 55 pruned.
# [I 2025-02-25 16:28:39,476] Trial 56 finished with value: 0.05690131103619933 and parameters: {'lr': 0.00228370288900957, 'batch_size': 32, 'step_size': 7, 'gamma': 0.8655507248473863}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:39,534] Trial 57 pruned.
# [I 2025-02-25 16:28:39,629] Trial 58 pruned.
# [I 2025-02-25 16:28:39,768] Trial 59 pruned.
# [I 2025-02-25 16:28:39,865] Trial 60 pruned.
# [I 2025-02-25 16:28:43,332] Trial 61 finished with value: 0.045023058948572725 and parameters: {'lr': 0.009162570932534237, 'batch_size': 32, 'step_size': 11, 'gamma': 0.8225031343563242}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:43,425] Trial 62 pruned.
# [I 2025-02-25 16:28:43,531] Trial 63 pruned.
# [I 2025-02-25 16:28:47,872] Trial 64 finished with value: 0.04709513869602233 and parameters: {'lr': 0.01914422628639819, 'batch_size': 32, 'step_size': 8, 'gamma': 0.8647436927121477}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:47,984] Trial 65 pruned.
# [I 2025-02-25 16:28:48,087] Trial 66 pruned.
# [I 2025-02-25 16:28:48,158] Trial 67 pruned.
# [I 2025-02-25 16:28:48,252] Trial 68 pruned.
# [I 2025-02-25 16:28:48,357] Trial 69 pruned.
# [I 2025-02-25 16:28:51,792] Trial 70 finished with value: 0.04455756675451994 and parameters: {'lr': 0.004659600340229484, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8235909262683635}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:51,885] Trial 71 pruned.
# [I 2025-02-25 16:28:52,060] Trial 72 pruned.
# [I 2025-02-25 16:28:52,172] Trial 73 pruned.
# [I 2025-02-25 16:28:52,338] Trial 74 pruned.
# [I 2025-02-25 16:28:55,804] Trial 75 finished with value: 0.04934815224260092 and parameters: {'lr': 0.008777134930077006, 'batch_size': 32, 'step_size': 19, 'gamma': 0.7604349632645753}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:56,287] Trial 76 pruned.
# [I 2025-02-25 16:28:56,377] Trial 77 pruned.
# [I 2025-02-25 16:28:59,752] Trial 78 finished with value: 0.049821294262073934 and parameters: {'lr': 0.00394951512736192, 'batch_size': 32, 'step_size': 20, 'gamma': 0.7275545187806558}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:28:59,844] Trial 79 pruned.
# [I 2025-02-25 16:29:02,213] Trial 80 pruned.
# [I 2025-02-25 16:29:02,336] Trial 81 pruned.
# [I 2025-02-25 16:29:02,438] Trial 82 pruned.
# [I 2025-02-25 16:29:02,542] Trial 83 pruned.
# [I 2025-02-25 16:29:02,640] Trial 84 pruned.
# [I 2025-02-25 16:29:02,754] Trial 85 pruned.
# [I 2025-02-25 16:29:02,917] Trial 86 pruned.
# [I 2025-02-25 16:29:03,091] Trial 87 pruned.
# [I 2025-02-25 16:29:03,195] Trial 88 pruned.
# [I 2025-02-25 16:29:03,300] Trial 89 pruned.
# [I 2025-02-25 16:29:03,764] Trial 90 pruned.
# [I 2025-02-25 16:29:03,833] Trial 91 pruned.
# [I 2025-02-25 16:29:03,903] Trial 92 pruned.
# [I 2025-02-25 16:29:03,997] Trial 93 pruned.
# [I 2025-02-25 16:29:04,092] Trial 94 pruned.
# [I 2025-02-25 16:29:04,156] Trial 95 pruned.
# [I 2025-02-25 16:29:04,439] Trial 96 pruned.
# [I 2025-02-25 16:29:04,546] Trial 97 pruned.
# [I 2025-02-25 16:29:04,638] Trial 98 pruned.
# [I 2025-02-25 16:29:04,746] Trial 99 pruned.
# [I 2025-02-25 16:29:04,862] Trial 100 pruned.
# [I 2025-02-25 16:29:04,980] Trial 101 pruned.
# [I 2025-02-25 16:29:05,083] Trial 102 pruned.
# [I 2025-02-25 16:29:05,264] Trial 103 pruned.
# [I 2025-02-25 16:29:05,363] Trial 104 pruned.
# [I 2025-02-25 16:29:05,454] Trial 105 pruned.
# [I 2025-02-25 16:29:08,944] Trial 106 finished with value: 0.04905637772753835 and parameters: {'lr': 0.0043817464974567144, 'batch_size': 32, 'step_size': 11, 'gamma': 0.7744096647347396}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:29:09,048] Trial 107 pruned.
# [I 2025-02-25 16:29:09,252] Trial 108 pruned.
# [I 2025-02-25 16:29:09,777] Trial 109 pruned.
# [I 2025-02-25 16:29:09,868] Trial 110 pruned.
# [I 2025-02-25 16:29:09,963] Trial 111 pruned.
# [I 2025-02-25 16:29:10,084] Trial 112 pruned.
# [I 2025-02-25 16:29:10,191] Trial 113 pruned.
# [I 2025-02-25 16:29:10,303] Trial 114 pruned.
# [I 2025-02-25 16:29:10,407] Trial 115 pruned.
# [I 2025-02-25 16:29:10,571] Trial 116 pruned.
# [I 2025-02-25 16:29:10,725] Trial 117 pruned.
# [I 2025-02-25 16:29:10,818] Trial 118 pruned.
# [I 2025-02-25 16:29:13,605] Trial 119 pruned.
# [I 2025-02-25 16:29:17,158] Trial 120 finished with value: 0.0475517368176952 and parameters: {'lr': 0.0048948103952218824, 'batch_size': 32, 'step_size': 19, 'gamma': 0.8301244906928926}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:29:17,253] Trial 121 pruned.
# [I 2025-02-25 16:29:17,346] Trial 122 pruned.
# [I 2025-02-25 16:29:17,473] Trial 123 pruned.
# [I 2025-02-25 16:29:20,965] Trial 124 finished with value: 0.05081882432568818 and parameters: {'lr': 0.003228023408752251, 'batch_size': 32, 'step_size': 19, 'gamma': 0.756524630074027}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:29:21,141] Trial 125 pruned.
# [I 2025-02-25 16:29:24,568] Trial 126 finished with value: 0.05066124955192208 and parameters: {'lr': 0.007867367674879722, 'batch_size': 32, 'step_size': 18, 'gamma': 0.7633913528491262}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:29:24,743] Trial 127 pruned.
# [I 2025-02-25 16:29:28,244] Trial 128 finished with value: 0.048498519230633974 and parameters: {'lr': 0.005375589522867693, 'batch_size': 32, 'step_size': 20, 'gamma': 0.7155173055627388}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:29:28,336] Trial 129 pruned.
# [I 2025-02-25 16:29:28,435] Trial 130 pruned.
# [I 2025-02-25 16:29:28,535] Trial 131 pruned.
# [I 2025-02-25 16:29:28,640] Trial 132 pruned.
# [I 2025-02-25 16:29:28,830] Trial 133 pruned.
# [I 2025-02-25 16:29:29,003] Trial 134 pruned.
# [I 2025-02-25 16:29:29,216] Trial 135 pruned.
# [I 2025-02-25 16:29:29,315] Trial 136 pruned.
# [I 2025-02-25 16:29:29,911] Trial 137 pruned.
# [I 2025-02-25 16:29:30,010] Trial 138 pruned.
# [I 2025-02-25 16:29:30,135] Trial 139 pruned.
# [I 2025-02-25 16:29:30,236] Trial 140 pruned.
# [I 2025-02-25 16:29:30,302] Trial 141 pruned.
# [I 2025-02-25 16:29:30,396] Trial 142 pruned.
# [I 2025-02-25 16:29:30,579] Trial 143 pruned.
# [I 2025-02-25 16:29:30,678] Trial 144 pruned.
# [I 2025-02-25 16:29:30,777] Trial 145 pruned.
# [I 2025-02-25 16:29:30,877] Trial 146 pruned.
# [I 2025-02-25 16:29:30,969] Trial 147 pruned.
# [I 2025-02-25 16:29:31,141] Trial 148 pruned.
# [I 2025-02-25 16:29:31,283] Trial 149 pruned.
# [I 2025-02-25 16:29:31,398] Trial 150 pruned.
# [I 2025-02-25 16:29:31,496] Trial 151 pruned.
# [I 2025-02-25 16:29:31,617] Trial 152 pruned.
# [I 2025-02-25 16:29:31,750] Trial 153 pruned.
# [I 2025-02-25 16:29:31,845] Trial 154 pruned.
# [I 2025-02-25 16:29:31,959] Trial 155 pruned.
# [I 2025-02-25 16:29:32,063] Trial 156 pruned.
# [I 2025-02-25 16:29:32,194] Trial 157 pruned.
# [I 2025-02-25 16:29:32,514] Trial 158 pruned.
# [I 2025-02-25 16:29:32,578] Trial 159 pruned.
# [I 2025-02-25 16:29:32,675] Trial 160 pruned.
# [I 2025-02-25 16:29:32,787] Trial 161 pruned.
# [I 2025-02-25 16:29:32,876] Trial 162 pruned.
# [I 2025-02-25 16:29:36,308] Trial 163 finished with value: 0.04932673426810652 and parameters: {'lr': 0.004682302423367371, 'batch_size': 32, 'step_size': 12, 'gamma': 0.8029314303173847}. Best is trial 0 with value: 0.042676265409681946.
# [I 2025-02-25 16:29:36,407] Trial 164 pruned.
# [I 2025-02-25 16:29:36,501] Trial 165 pruned.
# [I 2025-02-25 16:29:36,637] Trial 166 pruned.
# [I 2025-02-25 16:29:38,157] Trial 167 pruned.
# [I 2025-02-25 16:29:38,305] Trial 168 pruned.
# [I 2025-02-25 16:29:38,400] Trial 169 pruned.
# [I 2025-02-25 16:29:38,519] Trial 170 pruned.
# [I 2025-02-25 16:29:38,615] Trial 171 pruned.
# [I 2025-02-25 16:29:38,715] Trial 172 pruned.
# [I 2025-02-25 16:29:38,816] Trial 173 pruned.
# [I 2025-02-25 16:29:39,058] Trial 174 pruned.
# [I 2025-02-25 16:29:42,510] Trial 175 finished with value: 0.04141207743668929 and parameters: {'lr': 0.006917492934198781, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8329962959455544}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:29:42,602] Trial 176 pruned.
# [I 2025-02-25 16:29:42,704] Trial 177 pruned.
# [I 2025-02-25 16:29:42,783] Trial 178 pruned.
# [I 2025-02-25 16:29:42,886] Trial 179 pruned.
# [I 2025-02-25 16:29:42,985] Trial 180 pruned.
# [I 2025-02-25 16:29:43,079] Trial 181 pruned.
# [I 2025-02-25 16:29:46,591] Trial 182 finished with value: 0.04756975581403822 and parameters: {'lr': 0.007749343487293973, 'batch_size': 32, 'step_size': 20, 'gamma': 0.751443955708856}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:29:46,692] Trial 183 pruned.
# [I 2025-02-25 16:29:50,342] Trial 184 finished with value: 0.048072239267639816 and parameters: {'lr': 0.006221521243973143, 'batch_size': 32, 'step_size': 19, 'gamma': 0.7310888255167256}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:29:51,877] Trial 185 pruned.
# [I 2025-02-25 16:29:51,990] Trial 186 pruned.
# [I 2025-02-25 16:29:52,090] Trial 187 pruned.
# [I 2025-02-25 16:29:52,248] Trial 188 pruned.
# [I 2025-02-25 16:29:52,341] Trial 189 pruned.
# [I 2025-02-25 16:29:52,521] Trial 190 pruned.
# [I 2025-02-25 16:29:52,620] Trial 191 pruned.
# [I 2025-02-25 16:29:52,803] Trial 192 pruned.
# [I 2025-02-25 16:29:52,909] Trial 193 pruned.
# [I 2025-02-25 16:29:53,016] Trial 194 pruned.
# [I 2025-02-25 16:29:53,108] Trial 195 pruned.
# [I 2025-02-25 16:29:53,199] Trial 196 pruned.
# [I 2025-02-25 16:29:53,281] Trial 197 pruned.
# [I 2025-02-25 16:29:56,785] Trial 198 finished with value: 0.05077829628135078 and parameters: {'lr': 0.37442650558432927, 'batch_size': 32, 'step_size': 19, 'gamma': 0.47354380705612353}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:29:56,878] Trial 199 pruned.
# [I 2025-02-25 16:29:57,028] Trial 200 pruned.
# [I 2025-02-25 16:29:57,250] Trial 201 pruned.
# [I 2025-02-25 16:29:57,346] Trial 202 pruned.
# [I 2025-02-25 16:29:57,760] Trial 203 pruned.
# [I 2025-02-25 16:29:57,869] Trial 204 pruned.
# [I 2025-02-25 16:29:58,020] Trial 205 pruned.
# [I 2025-02-25 16:29:58,132] Trial 206 pruned.
# [I 2025-02-25 16:29:58,315] Trial 207 pruned.
# [I 2025-02-25 16:29:58,407] Trial 208 pruned.
# [I 2025-02-25 16:29:58,554] Trial 209 pruned.
# [I 2025-02-25 16:30:02,128] Trial 210 finished with value: 0.04572753980755806 and parameters: {'lr': 0.009089233682947876, 'batch_size': 32, 'step_size': 20, 'gamma': 0.7981590313161054}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:02,231] Trial 211 pruned.
# [I 2025-02-25 16:30:02,322] Trial 212 pruned.
# [I 2025-02-25 16:30:02,416] Trial 213 pruned.
# [I 2025-02-25 16:30:02,533] Trial 214 pruned.
# [I 2025-02-25 16:30:02,629] Trial 215 pruned.
# [I 2025-02-25 16:30:02,748] Trial 216 pruned.
# [I 2025-02-25 16:30:02,848] Trial 217 pruned.
# [I 2025-02-25 16:30:02,950] Trial 218 pruned.
# [I 2025-02-25 16:30:03,020] Trial 219 pruned.
# [I 2025-02-25 16:30:03,129] Trial 220 pruned.
# [I 2025-02-25 16:30:03,254] Trial 221 pruned.
# [I 2025-02-25 16:30:03,362] Trial 222 pruned.
# [I 2025-02-25 16:30:04,794] Trial 223 pruned.
# [I 2025-02-25 16:30:04,923] Trial 224 pruned.
# [I 2025-02-25 16:30:05,044] Trial 225 pruned.
# [I 2025-02-25 16:30:05,147] Trial 226 pruned.
# [I 2025-02-25 16:30:05,240] Trial 227 pruned.
# [I 2025-02-25 16:30:05,342] Trial 228 pruned.
# [I 2025-02-25 16:30:05,466] Trial 229 pruned.
# [I 2025-02-25 16:30:05,568] Trial 230 pruned.
# [I 2025-02-25 16:30:05,676] Trial 231 pruned.
# [I 2025-02-25 16:30:05,774] Trial 232 pruned.
# [I 2025-02-25 16:30:05,865] Trial 233 pruned.
# [I 2025-02-25 16:30:05,964] Trial 234 pruned.
# [I 2025-02-25 16:30:06,084] Trial 235 pruned.
# [I 2025-02-25 16:30:06,191] Trial 236 pruned.
# [I 2025-02-25 16:30:06,260] Trial 237 pruned.
# [I 2025-02-25 16:30:06,407] Trial 238 pruned.
# [I 2025-02-25 16:30:09,895] Trial 239 finished with value: 0.04320736764930189 and parameters: {'lr': 0.0035633670324286097, 'batch_size': 32, 'step_size': 20, 'gamma': 0.824045212812745}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:09,991] Trial 240 pruned.
# [I 2025-02-25 16:30:10,170] Trial 241 pruned.
# [I 2025-02-25 16:30:10,276] Trial 242 pruned.
# [I 2025-02-25 16:30:10,380] Trial 243 pruned.
# [I 2025-02-25 16:30:10,472] Trial 244 pruned.
# [I 2025-02-25 16:30:10,575] Trial 245 pruned.
# [I 2025-02-25 16:30:10,787] Trial 246 pruned.
# [I 2025-02-25 16:30:10,880] Trial 247 pruned.
# [I 2025-02-25 16:30:10,975] Trial 248 pruned.
# [I 2025-02-25 16:30:11,090] Trial 249 pruned.
# [I 2025-02-25 16:30:11,219] Trial 250 pruned.
# [I 2025-02-25 16:30:11,396] Trial 251 pruned.
# [I 2025-02-25 16:30:15,036] Trial 252 finished with value: 0.041978838853538036 and parameters: {'lr': 0.007244114916309567, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8389321154845606}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:15,146] Trial 253 pruned.
# [I 2025-02-25 16:30:15,256] Trial 254 pruned.
# [I 2025-02-25 16:30:15,365] Trial 255 pruned.
# [I 2025-02-25 16:30:15,448] Trial 256 pruned.
# [I 2025-02-25 16:30:15,574] Trial 257 pruned.
# [I 2025-02-25 16:30:15,690] Trial 258 pruned.
# [I 2025-02-25 16:30:15,808] Trial 259 pruned.
# [I 2025-02-25 16:30:15,910] Trial 260 pruned.
# [I 2025-02-25 16:30:16,046] Trial 261 pruned.
# [I 2025-02-25 16:30:16,150] Trial 262 pruned.
# [I 2025-02-25 16:30:16,268] Trial 263 pruned.
# [I 2025-02-25 16:30:16,452] Trial 264 pruned.
# [I 2025-02-25 16:30:16,558] Trial 265 pruned.
# [I 2025-02-25 16:30:16,725] Trial 266 pruned.
# [I 2025-02-25 16:30:16,826] Trial 267 pruned.
# [I 2025-02-25 16:30:16,925] Trial 268 pruned.
# [I 2025-02-25 16:30:17,019] Trial 269 pruned.
# [I 2025-02-25 16:30:17,098] Trial 270 pruned.
# [I 2025-02-25 16:30:17,212] Trial 271 pruned.
# [I 2025-02-25 16:30:17,310] Trial 272 pruned.
# [I 2025-02-25 16:30:17,550] Trial 273 pruned.
# [I 2025-02-25 16:30:17,649] Trial 274 pruned.
# [I 2025-02-25 16:30:17,754] Trial 275 pruned.
# [I 2025-02-25 16:30:17,862] Trial 276 pruned.
# [I 2025-02-25 16:30:17,973] Trial 277 pruned.
# [I 2025-02-25 16:30:18,087] Trial 278 pruned.
# [I 2025-02-25 16:30:18,218] Trial 279 pruned.
# [I 2025-02-25 16:30:18,321] Trial 280 pruned.
# [I 2025-02-25 16:30:18,393] Trial 281 pruned.
# [I 2025-02-25 16:30:18,571] Trial 282 pruned.
# [I 2025-02-25 16:30:23,565] Trial 283 finished with value: 0.05298170167952776 and parameters: {'lr': 0.005165135336511966, 'batch_size': 32, 'step_size': 18, 'gamma': 0.8331539119129627}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:23,684] Trial 284 pruned.
# [I 2025-02-25 16:30:23,802] Trial 285 pruned.
# [I 2025-02-25 16:30:23,903] Trial 286 pruned.
# [I 2025-02-25 16:30:24,003] Trial 287 pruned.
# [I 2025-02-25 16:30:24,253] Trial 288 pruned.
# [I 2025-02-25 16:30:24,411] Trial 289 pruned.
# [I 2025-02-25 16:30:24,581] Trial 290 pruned.
# [I 2025-02-25 16:30:24,685] Trial 291 pruned.
# [I 2025-02-25 16:30:26,082] Trial 292 pruned.
# [I 2025-02-25 16:30:26,180] Trial 293 pruned.
# [I 2025-02-25 16:30:26,293] Trial 294 pruned.
# [I 2025-02-25 16:30:26,373] Trial 295 pruned.
# [I 2025-02-25 16:30:26,490] Trial 296 pruned.
# [I 2025-02-25 16:30:30,343] Trial 297 finished with value: 0.0438014940591529 and parameters: {'lr': 0.005942789584199924, 'batch_size': 32, 'step_size': 19, 'gamma': 0.8028934308756085}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:30,526] Trial 298 pruned.
# [I 2025-02-25 16:30:30,617] Trial 299 pruned.
# [I 2025-02-25 16:30:30,736] Trial 300 pruned.
# [I 2025-02-25 16:30:30,841] Trial 301 pruned.
# [I 2025-02-25 16:30:30,942] Trial 302 pruned.
# [I 2025-02-25 16:30:31,052] Trial 303 pruned.
# [I 2025-02-25 16:30:31,173] Trial 304 pruned.
# [I 2025-02-25 16:30:31,298] Trial 305 pruned.
# [I 2025-02-25 16:30:31,505] Trial 306 pruned.
# [I 2025-02-25 16:30:31,582] Trial 307 pruned.
# [I 2025-02-25 16:30:31,702] Trial 308 pruned.
# [I 2025-02-25 16:30:31,879] Trial 309 pruned.
# [I 2025-02-25 16:30:31,979] Trial 310 pruned.
# [I 2025-02-25 16:30:32,084] Trial 311 pruned.
# [I 2025-02-25 16:30:32,307] Trial 312 pruned.
# [I 2025-02-25 16:30:32,404] Trial 313 pruned.
# [I 2025-02-25 16:30:32,511] Trial 314 pruned.
# [I 2025-02-25 16:30:32,614] Trial 315 pruned.
# [I 2025-02-25 16:30:32,748] Trial 316 pruned.
# [I 2025-02-25 16:30:32,853] Trial 317 pruned.
# [I 2025-02-25 16:30:32,954] Trial 318 pruned.
# [I 2025-02-25 16:30:33,066] Trial 319 pruned.
# [I 2025-02-25 16:30:33,191] Trial 320 pruned.
# [I 2025-02-25 16:30:33,261] Trial 321 pruned.
# [I 2025-02-25 16:30:33,355] Trial 322 pruned.
# [I 2025-02-25 16:30:33,458] Trial 323 pruned.
# [I 2025-02-25 16:30:33,596] Trial 324 pruned.
# [I 2025-02-25 16:30:33,716] Trial 325 pruned.
# [I 2025-02-25 16:30:37,213] Trial 326 finished with value: 0.04755668411962688 and parameters: {'lr': 0.004452704189285082, 'batch_size': 32, 'step_size': 19, 'gamma': 0.8491847353047418}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:37,312] Trial 327 pruned.
# [I 2025-02-25 16:30:37,416] Trial 328 pruned.
# [I 2025-02-25 16:30:37,539] Trial 329 pruned.
# [I 2025-02-25 16:30:37,720] Trial 330 pruned.
# [I 2025-02-25 16:30:41,210] Trial 331 finished with value: 0.04663112369598821 and parameters: {'lr': 0.008794057718193733, 'batch_size': 32, 'step_size': 19, 'gamma': 0.48255483236112845}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:41,311] Trial 332 pruned.
# [I 2025-02-25 16:30:41,423] Trial 333 pruned.
# [I 2025-02-25 16:30:41,549] Trial 334 pruned.
# [I 2025-02-25 16:30:41,643] Trial 335 pruned.
# [I 2025-02-25 16:30:41,744] Trial 336 pruned.
# [I 2025-02-25 16:30:41,921] Trial 337 pruned.
# [I 2025-02-25 16:30:42,044] Trial 338 pruned.
# [I 2025-02-25 16:30:42,141] Trial 339 pruned.
# [I 2025-02-25 16:30:42,312] Trial 340 pruned.
# [I 2025-02-25 16:30:42,494] Trial 341 pruned.
# [I 2025-02-25 16:30:42,589] Trial 342 pruned.
# [I 2025-02-25 16:30:42,684] Trial 343 pruned.
# [I 2025-02-25 16:30:42,900] Trial 344 pruned.
# [I 2025-02-25 16:30:43,092] Trial 345 pruned.
# [I 2025-02-25 16:30:43,192] Trial 346 pruned.
# [I 2025-02-25 16:30:43,299] Trial 347 pruned.
# [I 2025-02-25 16:30:43,419] Trial 348 pruned.
# [I 2025-02-25 16:30:43,520] Trial 349 pruned.
# [I 2025-02-25 16:30:43,712] Trial 350 pruned.
# [I 2025-02-25 16:30:43,899] Trial 351 pruned.
# [I 2025-02-25 16:30:44,029] Trial 352 pruned.
# [I 2025-02-25 16:30:44,122] Trial 353 pruned.
# [I 2025-02-25 16:30:47,677] Trial 354 finished with value: 0.04929532203823328 and parameters: {'lr': 0.005896016138302263, 'batch_size': 32, 'step_size': 19, 'gamma': 0.6813043195233766}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:47,777] Trial 355 pruned.
# [I 2025-02-25 16:30:47,872] Trial 356 pruned.
# [I 2025-02-25 16:30:47,977] Trial 357 pruned.
# [I 2025-02-25 16:30:48,086] Trial 358 pruned.
# [I 2025-02-25 16:30:48,215] Trial 359 pruned.
# [I 2025-02-25 16:30:48,321] Trial 360 pruned.
# [I 2025-02-25 16:30:49,599] Trial 361 pruned.
# [I 2025-02-25 16:30:49,760] Trial 362 pruned.
# [I 2025-02-25 16:30:49,944] Trial 363 pruned.
# [I 2025-02-25 16:30:50,036] Trial 364 pruned.
# [I 2025-02-25 16:30:50,152] Trial 365 pruned.
# [I 2025-02-25 16:30:50,253] Trial 366 pruned.
# [I 2025-02-25 16:30:50,348] Trial 367 pruned.
# [I 2025-02-25 16:30:50,561] Trial 368 pruned.
# [I 2025-02-25 16:30:51,848] Trial 369 pruned.
# [I 2025-02-25 16:30:51,947] Trial 370 pruned.
# [I 2025-02-25 16:30:52,149] Trial 371 pruned.
# [I 2025-02-25 16:30:55,629] Trial 372 finished with value: 0.04439416463719681 and parameters: {'lr': 0.0054623890008998815, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8483296739025852}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:30:56,196] Trial 373 pruned.
# [I 2025-02-25 16:30:56,301] Trial 374 pruned.
# [I 2025-02-25 16:30:56,428] Trial 375 pruned.
# [I 2025-02-25 16:30:56,544] Trial 376 pruned.
# [I 2025-02-25 16:30:56,643] Trial 377 pruned.
# [I 2025-02-25 16:30:56,805] Trial 378 pruned.
# [I 2025-02-25 16:30:56,938] Trial 379 pruned.
# [I 2025-02-25 16:30:57,041] Trial 380 pruned.
# [I 2025-02-25 16:30:57,148] Trial 381 pruned.
# [I 2025-02-25 16:30:57,260] Trial 382 pruned.
# [I 2025-02-25 16:30:57,353] Trial 383 pruned.
# [I 2025-02-25 16:30:57,457] Trial 384 pruned.
# [I 2025-02-25 16:30:57,641] Trial 385 pruned.
# [I 2025-02-25 16:30:57,734] Trial 386 pruned.
# [I 2025-02-25 16:30:57,852] Trial 387 pruned.
# [I 2025-02-25 16:30:58,013] Trial 388 pruned.
# [I 2025-02-25 16:30:58,195] Trial 389 pruned.
# [I 2025-02-25 16:30:58,302] Trial 390 pruned.
# [I 2025-02-25 16:30:58,404] Trial 391 pruned.
# [I 2025-02-25 16:30:58,532] Trial 392 pruned.
# [I 2025-02-25 16:30:58,647] Trial 393 pruned.
# [I 2025-02-25 16:30:58,770] Trial 394 pruned.
# [I 2025-02-25 16:30:58,910] Trial 395 pruned.
# [I 2025-02-25 16:30:59,014] Trial 396 pruned.
# [I 2025-02-25 16:30:59,153] Trial 397 pruned.
# [I 2025-02-25 16:30:59,254] Trial 398 pruned.
# [I 2025-02-25 16:30:59,401] Trial 399 pruned.
# [I 2025-02-25 16:30:59,505] Trial 400 pruned.
# [I 2025-02-25 16:30:59,632] Trial 401 pruned.
# [I 2025-02-25 16:30:59,741] Trial 402 pruned.
# [I 2025-02-25 16:30:59,969] Trial 403 pruned.
# [I 2025-02-25 16:31:00,075] Trial 404 pruned.
# [I 2025-02-25 16:31:00,231] Trial 405 pruned.
# [I 2025-02-25 16:31:00,327] Trial 406 pruned.
# [I 2025-02-25 16:31:00,453] Trial 407 pruned.
# [I 2025-02-25 16:31:00,564] Trial 408 pruned.
# [I 2025-02-25 16:31:00,674] Trial 409 pruned.
# [I 2025-02-25 16:31:01,125] Trial 410 pruned.
# [I 2025-02-25 16:31:05,737] Trial 411 finished with value: 0.046566738514229655 and parameters: {'lr': 0.005100297326879913, 'batch_size': 32, 'step_size': 20, 'gamma': 0.7808455472690964}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:31:05,848] Trial 412 pruned.
# [I 2025-02-25 16:31:05,956] Trial 413 pruned.
# [I 2025-02-25 16:31:06,063] Trial 414 pruned.
# [I 2025-02-25 16:31:06,247] Trial 415 pruned.
# [I 2025-02-25 16:31:06,387] Trial 416 pruned.
# [I 2025-02-25 16:31:06,499] Trial 417 pruned.
# [I 2025-02-25 16:31:06,607] Trial 418 pruned.
# [I 2025-02-25 16:31:06,710] Trial 419 pruned.
# [I 2025-02-25 16:31:06,811] Trial 420 pruned.
# [I 2025-02-25 16:31:06,925] Trial 421 pruned.
# [I 2025-02-25 16:31:07,034] Trial 422 pruned.
# [I 2025-02-25 16:31:10,875] Trial 423 finished with value: 0.046705259243026376 and parameters: {'lr': 0.005062998491394687, 'batch_size': 32, 'step_size': 19, 'gamma': 0.8429492232284229}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:31:10,968] Trial 424 pruned.
# [I 2025-02-25 16:31:11,145] Trial 425 pruned.
# [I 2025-02-25 16:31:11,337] Trial 426 pruned.
# [I 2025-02-25 16:31:11,451] Trial 427 pruned.
# [I 2025-02-25 16:31:11,629] Trial 428 pruned.
# [I 2025-02-25 16:31:11,735] Trial 429 pruned.
# [I 2025-02-25 16:31:11,848] Trial 430 pruned.
# [I 2025-02-25 16:31:11,955] Trial 431 pruned.
# [I 2025-02-25 16:31:12,068] Trial 432 pruned.
# [I 2025-02-25 16:31:12,273] Trial 433 pruned.
# [I 2025-02-25 16:31:12,394] Trial 434 pruned.
# [I 2025-02-25 16:31:12,502] Trial 435 pruned.
# [I 2025-02-25 16:31:16,227] Trial 436 finished with value: 0.05134689633268863 and parameters: {'lr': 0.004811045566784859, 'batch_size': 32, 'step_size': 13, 'gamma': 0.8325325006347021}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:31:16,343] Trial 437 pruned.
# [I 2025-02-25 16:31:16,530] Trial 438 pruned.
# [I 2025-02-25 16:31:16,630] Trial 439 pruned.
# [I 2025-02-25 16:31:16,728] Trial 440 pruned.
# [I 2025-02-25 16:31:16,845] Trial 441 pruned.
# [I 2025-02-25 16:31:16,960] Trial 442 pruned.
# [I 2025-02-25 16:31:17,045] Trial 443 pruned.
# [I 2025-02-25 16:31:17,148] Trial 444 pruned.
# [I 2025-02-25 16:31:17,327] Trial 445 pruned.
# [I 2025-02-25 16:31:17,436] Trial 446 pruned.
# [I 2025-02-25 16:31:17,581] Trial 447 pruned.
# [I 2025-02-25 16:31:17,708] Trial 448 pruned.
# [I 2025-02-25 16:31:18,185] Trial 449 pruned.
# [I 2025-02-25 16:31:18,334] Trial 450 pruned.
# [I 2025-02-25 16:31:18,441] Trial 451 pruned.
# [I 2025-02-25 16:31:18,628] Trial 452 pruned.
# [I 2025-02-25 16:31:18,759] Trial 453 pruned.
# [I 2025-02-25 16:31:18,863] Trial 454 pruned.
# [I 2025-02-25 16:31:19,037] Trial 455 pruned.
# [I 2025-02-25 16:31:19,273] Trial 456 pruned.
# [I 2025-02-25 16:31:19,381] Trial 457 pruned.
# [I 2025-02-25 16:31:19,501] Trial 458 pruned.
# [I 2025-02-25 16:31:19,621] Trial 459 pruned.
# [I 2025-02-25 16:31:19,821] Trial 460 pruned.
# [I 2025-02-25 16:31:19,949] Trial 461 pruned.
# [I 2025-02-25 16:31:20,068] Trial 462 pruned.
# [I 2025-02-25 16:31:20,178] Trial 463 pruned.
# [I 2025-02-25 16:31:20,281] Trial 464 pruned.
# [I 2025-02-25 16:31:20,371] Trial 465 pruned.
# [I 2025-02-25 16:31:20,465] Trial 466 pruned.
# [I 2025-02-25 16:31:20,532] Trial 467 pruned.
# [I 2025-02-25 16:31:20,662] Trial 468 pruned.
# [I 2025-02-25 16:31:20,890] Trial 469 pruned.
# [I 2025-02-25 16:31:21,001] Trial 470 pruned.
# [I 2025-02-25 16:31:21,135] Trial 471 pruned.
# [I 2025-02-25 16:31:21,323] Trial 472 pruned.
# [I 2025-02-25 16:31:21,527] Trial 473 pruned.
# [I 2025-02-25 16:31:21,641] Trial 474 pruned.
# [I 2025-02-25 16:31:21,844] Trial 475 pruned.
# [I 2025-02-25 16:31:22,022] Trial 476 pruned.
# [I 2025-02-25 16:31:22,122] Trial 477 pruned.
# [I 2025-02-25 16:31:22,225] Trial 478 pruned.
# [I 2025-02-25 16:31:22,374] Trial 479 pruned.
# [I 2025-02-25 16:31:22,578] Trial 480 pruned.
# [I 2025-02-25 16:31:22,785] Trial 481 pruned.
# [I 2025-02-25 16:31:22,910] Trial 482 pruned.
# [I 2025-02-25 16:31:23,025] Trial 483 pruned.
# [I 2025-02-25 16:31:23,144] Trial 484 pruned.
# [I 2025-02-25 16:31:23,265] Trial 485 pruned.
# [I 2025-02-25 16:31:23,376] Trial 486 pruned.
# [I 2025-02-25 16:31:23,513] Trial 487 pruned.
# [I 2025-02-25 16:31:23,709] Trial 488 pruned.
# [I 2025-02-25 16:31:23,817] Trial 489 pruned.
# [I 2025-02-25 16:31:23,897] Trial 490 pruned.
# [I 2025-02-25 16:31:24,019] Trial 491 pruned.
# [I 2025-02-25 16:31:24,141] Trial 492 pruned.
# [I 2025-02-25 16:31:24,251] Trial 493 pruned.
# [I 2025-02-25 16:31:24,377] Trial 494 pruned.
# [I 2025-02-25 16:31:24,591] Trial 495 pruned.
# [I 2025-02-25 16:31:24,726] Trial 496 pruned.
# [I 2025-02-25 16:31:24,842] Trial 497 pruned.
# [I 2025-02-25 16:31:24,979] Trial 498 pruned.
# [I 2025-02-25 16:31:25,112] Trial 499 pruned.
# [I 2025-02-25 16:31:25,251] Trial 500 pruned.
# [I 2025-02-25 16:31:25,397] Trial 501 pruned.
# [I 2025-02-25 16:31:25,520] Trial 502 pruned.
# [I 2025-02-25 16:31:25,645] Trial 503 pruned.
# [I 2025-02-25 16:31:25,750] Trial 504 pruned.
# [I 2025-02-25 16:31:25,858] Trial 505 pruned.
# [I 2025-02-25 16:31:25,963] Trial 506 pruned.
# [I 2025-02-25 16:31:26,063] Trial 507 pruned.
# [I 2025-02-25 16:31:26,159] Trial 508 pruned.
# [I 2025-02-25 16:31:26,258] Trial 509 pruned.
# [I 2025-02-25 16:31:26,377] Trial 510 pruned.
# [I 2025-02-25 16:31:26,465] Trial 511 pruned.
# [I 2025-02-25 16:31:26,565] Trial 512 pruned.
# [I 2025-02-25 16:31:26,662] Trial 513 pruned.
# [I 2025-02-25 16:31:26,762] Trial 514 pruned.
# [I 2025-02-25 16:31:26,873] Trial 515 pruned.
# [I 2025-02-25 16:31:27,050] Trial 516 pruned.
# [I 2025-02-25 16:31:27,161] Trial 517 pruned.
# [I 2025-02-25 16:31:27,351] Trial 518 pruned.
# [I 2025-02-25 16:31:27,450] Trial 519 pruned.
# [I 2025-02-25 16:31:27,560] Trial 520 pruned.
# [I 2025-02-25 16:31:27,664] Trial 521 pruned.
# [I 2025-02-25 16:31:27,783] Trial 522 pruned.
# [I 2025-02-25 16:31:27,906] Trial 523 pruned.
# [I 2025-02-25 16:31:28,019] Trial 524 pruned.
# [I 2025-02-25 16:31:28,136] Trial 525 pruned.
# [I 2025-02-25 16:31:28,242] Trial 526 pruned.
# [I 2025-02-25 16:31:28,381] Trial 527 pruned.
# [I 2025-02-25 16:31:28,501] Trial 528 pruned.
# [I 2025-02-25 16:31:28,632] Trial 529 pruned.
# [I 2025-02-25 16:31:28,748] Trial 530 pruned.
# [I 2025-02-25 16:31:28,847] Trial 531 pruned.
# [I 2025-02-25 16:31:28,969] Trial 532 pruned.
# [I 2025-02-25 16:31:29,073] Trial 533 pruned.
# [I 2025-02-25 16:31:29,175] Trial 534 pruned.
# [I 2025-02-25 16:31:29,300] Trial 535 pruned.
# [I 2025-02-25 16:31:29,402] Trial 536 pruned.
# [I 2025-02-25 16:31:29,539] Trial 537 pruned.
# [I 2025-02-25 16:31:29,705] Trial 538 pruned.
# [I 2025-02-25 16:31:29,828] Trial 539 pruned.
# [I 2025-02-25 16:31:30,009] Trial 540 pruned.
# [I 2025-02-25 16:31:30,115] Trial 541 pruned.
# [I 2025-02-25 16:31:30,224] Trial 542 pruned.
# [I 2025-02-25 16:31:30,350] Trial 543 pruned.
# [I 2025-02-25 16:31:30,467] Trial 544 pruned.
# [I 2025-02-25 16:31:30,580] Trial 545 pruned.
# [I 2025-02-25 16:31:30,682] Trial 546 pruned.
# [I 2025-02-25 16:31:30,808] Trial 547 pruned.
# [I 2025-02-25 16:31:31,003] Trial 548 pruned.
# [I 2025-02-25 16:31:31,112] Trial 549 pruned.
# [I 2025-02-25 16:31:31,214] Trial 550 pruned.
# [I 2025-02-25 16:31:31,309] Trial 551 pruned.
# [I 2025-02-25 16:31:31,413] Trial 552 pruned.
# [I 2025-02-25 16:31:31,497] Trial 553 pruned.
# [I 2025-02-25 16:31:31,607] Trial 554 pruned.
# [I 2025-02-25 16:31:31,712] Trial 555 pruned.
# [I 2025-02-25 16:31:31,825] Trial 556 pruned.
# [I 2025-02-25 16:31:31,934] Trial 557 pruned.
# [I 2025-02-25 16:31:32,036] Trial 558 pruned.
# [I 2025-02-25 16:31:32,135] Trial 559 pruned.
# [I 2025-02-25 16:31:32,243] Trial 560 pruned.
# [I 2025-02-25 16:31:32,420] Trial 561 pruned.
# [I 2025-02-25 16:31:32,523] Trial 562 pruned.
# [I 2025-02-25 16:31:32,629] Trial 563 pruned.
# [I 2025-02-25 16:31:32,750] Trial 564 pruned.
# [I 2025-02-25 16:31:32,851] Trial 565 pruned.
# [I 2025-02-25 16:31:32,991] Trial 566 pruned.
# [I 2025-02-25 16:31:33,136] Trial 567 pruned.
# [I 2025-02-25 16:31:33,250] Trial 568 pruned.
# [I 2025-02-25 16:31:33,384] Trial 569 pruned.
# [I 2025-02-25 16:31:33,500] Trial 570 pruned.
# [I 2025-02-25 16:31:33,625] Trial 571 pruned.
# [I 2025-02-25 16:31:33,739] Trial 572 pruned.
# [I 2025-02-25 16:31:33,848] Trial 573 pruned.
# [I 2025-02-25 16:31:34,052] Trial 574 pruned.
# [I 2025-02-25 16:31:34,145] Trial 575 pruned.
# [I 2025-02-25 16:31:34,260] Trial 576 pruned.
# [I 2025-02-25 16:31:34,444] Trial 577 pruned.
# [I 2025-02-25 16:31:38,165] Trial 578 finished with value: 0.04426766512915492 and parameters: {'lr': 0.005896597746508614, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8567614277283269}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:31:38,281] Trial 579 pruned.
# [I 2025-02-25 16:31:38,397] Trial 580 pruned.
# [I 2025-02-25 16:31:38,628] Trial 581 pruned.
# [I 2025-02-25 16:31:42,290] Trial 582 finished with value: 0.04238679085392505 and parameters: {'lr': 0.005602950333345499, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8624773650672298}. Best is trial 175 with value: 0.04141207743668929.
# [I 2025-02-25 16:31:42,398] Trial 583 pruned.
# [I 2025-02-25 16:31:42,603] Trial 584 pruned.
# [I 2025-02-25 16:31:43,498] Trial 585 pruned.
# [I 2025-02-25 16:31:43,622] Trial 586 pruned.
# [I 2025-02-25 16:31:43,737] Trial 587 pruned.
# [I 2025-02-25 16:31:44,210] Trial 588 pruned.
# [I 2025-02-25 16:31:47,934] Trial 589 finished with value: 0.03636084566824138 and parameters: {'lr': 0.007155597830171852, 'batch_size': 32, 'step_size': 20, 'gamma': 0.838242359901212}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:31:48,034] Trial 590 pruned.
# [I 2025-02-25 16:31:48,143] Trial 591 pruned.
# [I 2025-02-25 16:31:48,271] Trial 592 pruned.
# [I 2025-02-25 16:31:48,395] Trial 593 pruned.
# [I 2025-02-25 16:31:48,506] Trial 594 pruned.
# [I 2025-02-25 16:31:48,612] Trial 595 pruned.
# [I 2025-02-25 16:31:48,740] Trial 596 pruned.
# [I 2025-02-25 16:31:48,871] Trial 597 pruned.
# [I 2025-02-25 16:31:48,981] Trial 598 pruned.
# [I 2025-02-25 16:31:49,103] Trial 599 pruned.
# [I 2025-02-25 16:31:49,195] Trial 600 pruned.
# [I 2025-02-25 16:31:49,375] Trial 601 pruned.
# [I 2025-02-25 16:31:49,570] Trial 602 pruned.
# [I 2025-02-25 16:31:49,681] Trial 603 pruned.
# [I 2025-02-25 16:31:49,799] Trial 604 pruned.
# [I 2025-02-25 16:31:49,905] Trial 605 pruned.
# [I 2025-02-25 16:31:50,017] Trial 606 pruned.
# [I 2025-02-25 16:31:50,185] Trial 607 pruned.
# [I 2025-02-25 16:31:50,310] Trial 608 pruned.
# [I 2025-02-25 16:31:50,414] Trial 609 pruned.
# [I 2025-02-25 16:31:50,541] Trial 610 pruned.
# [I 2025-02-25 16:31:50,656] Trial 611 pruned.
# [I 2025-02-25 16:31:50,768] Trial 612 pruned.
# [I 2025-02-25 16:31:50,881] Trial 613 pruned.
# [I 2025-02-25 16:31:50,999] Trial 614 pruned.
# [I 2025-02-25 16:31:51,108] Trial 615 pruned.
# [I 2025-02-25 16:31:51,219] Trial 616 pruned.
# [I 2025-02-25 16:31:51,329] Trial 617 pruned.
# [I 2025-02-25 16:31:51,537] Trial 618 pruned.
# [I 2025-02-25 16:31:51,639] Trial 619 pruned.
# [I 2025-02-25 16:31:51,735] Trial 620 pruned.
# [I 2025-02-25 16:31:51,839] Trial 621 pruned.
# [I 2025-02-25 16:31:55,709] Trial 622 finished with value: 0.044584458926692605 and parameters: {'lr': 0.004531615997876025, 'batch_size': 32, 'step_size': 9, 'gamma': 0.8739958057615994}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:31:55,812] Trial 623 pruned.
# [I 2025-02-25 16:31:55,888] Trial 624 pruned.
# [I 2025-02-25 16:31:55,989] Trial 625 pruned.
# [I 2025-02-25 16:31:56,093] Trial 626 pruned.
# [I 2025-02-25 16:31:56,225] Trial 627 pruned.
# [I 2025-02-25 16:31:56,338] Trial 628 pruned.
# [I 2025-02-25 16:31:56,501] Trial 629 pruned.
# [I 2025-02-25 16:31:56,607] Trial 630 pruned.
# [I 2025-02-25 16:31:56,701] Trial 631 pruned.
# [I 2025-02-25 16:31:56,808] Trial 632 pruned.
# [I 2025-02-25 16:31:56,909] Trial 633 pruned.
# [I 2025-02-25 16:31:57,032] Trial 634 pruned.
# [I 2025-02-25 16:31:57,156] Trial 635 pruned.
# [I 2025-02-25 16:32:00,999] Trial 636 finished with value: 0.04964634915813804 and parameters: {'lr': 0.00790382568342826, 'batch_size': 32, 'step_size': 8, 'gamma': 0.853381569180263}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:01,143] Trial 637 pruned.
# [I 2025-02-25 16:32:01,259] Trial 638 pruned.
# [I 2025-02-25 16:32:06,196] Trial 639 finished with value: 0.03768547053914517 and parameters: {'lr': 0.009588592436447522, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8567674731870522}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:06,331] Trial 640 pruned.
# [I 2025-02-25 16:32:06,446] Trial 641 pruned.
# [I 2025-02-25 16:32:06,543] Trial 642 pruned.
# [I 2025-02-25 16:32:06,660] Trial 643 pruned.
# [I 2025-02-25 16:32:06,771] Trial 644 pruned.
# [I 2025-02-25 16:32:06,850] Trial 645 pruned.
# [I 2025-02-25 16:32:06,957] Trial 646 pruned.
# [I 2025-02-25 16:32:07,074] Trial 647 pruned.
# [I 2025-02-25 16:32:07,194] Trial 648 pruned.
# [I 2025-02-25 16:32:07,329] Trial 649 pruned.
# [I 2025-02-25 16:32:07,473] Trial 650 pruned.
# [I 2025-02-25 16:32:07,587] Trial 651 pruned.
# [I 2025-02-25 16:32:07,786] Trial 652 pruned.
# [I 2025-02-25 16:32:07,921] Trial 653 pruned.
# [I 2025-02-25 16:32:08,042] Trial 654 pruned.
# [I 2025-02-25 16:32:08,160] Trial 655 pruned.
# [I 2025-02-25 16:32:11,923] Trial 656 finished with value: 0.046431925788056105 and parameters: {'lr': 0.006962566914157611, 'batch_size': 32, 'step_size': 8, 'gamma': 0.8066519282228113}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:15,668] Trial 657 finished with value: 0.047523294342681766 and parameters: {'lr': 0.009289816330202616, 'batch_size': 32, 'step_size': 9, 'gamma': 0.8028143266249418}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:15,783] Trial 658 pruned.
# [I 2025-02-25 16:32:15,916] Trial 659 pruned.
# [I 2025-02-25 16:32:16,036] Trial 660 pruned.
# [I 2025-02-25 16:32:16,157] Trial 661 pruned.
# [I 2025-02-25 16:32:16,269] Trial 662 pruned.
# [I 2025-02-25 16:32:16,381] Trial 663 pruned.
# [I 2025-02-25 16:32:16,579] Trial 664 pruned.
# [I 2025-02-25 16:32:16,709] Trial 665 pruned.
# [I 2025-02-25 16:32:16,828] Trial 666 pruned.
# [I 2025-02-25 16:32:16,953] Trial 667 pruned.
# [I 2025-02-25 16:32:17,064] Trial 668 pruned.
# [I 2025-02-25 16:32:17,151] Trial 669 pruned.
# [I 2025-02-25 16:32:17,318] Trial 670 pruned.
# [I 2025-02-25 16:32:17,430] Trial 671 pruned.
# [I 2025-02-25 16:32:17,629] Trial 672 pruned.
# [I 2025-02-25 16:32:17,746] Trial 673 pruned.
# [I 2025-02-25 16:32:17,856] Trial 674 pruned.
# [I 2025-02-25 16:32:18,038] Trial 675 pruned.
# [I 2025-02-25 16:32:18,139] Trial 676 pruned.
# [I 2025-02-25 16:32:18,251] Trial 677 pruned.
# [I 2025-02-25 16:32:18,362] Trial 678 pruned.
# [I 2025-02-25 16:32:18,495] Trial 679 pruned.
# [I 2025-02-25 16:32:18,608] Trial 680 pruned.
# [I 2025-02-25 16:32:18,721] Trial 681 pruned.
# [I 2025-02-25 16:32:18,830] Trial 682 pruned.
# [I 2025-02-25 16:32:18,947] Trial 683 pruned.
# [I 2025-02-25 16:32:19,057] Trial 684 pruned.
# [I 2025-02-25 16:32:19,251] Trial 685 pruned.
# [I 2025-02-25 16:32:19,357] Trial 686 pruned.
# [I 2025-02-25 16:32:19,468] Trial 687 pruned.
# [I 2025-02-25 16:32:19,577] Trial 688 pruned.
# [I 2025-02-25 16:32:19,695] Trial 689 pruned.
# [I 2025-02-25 16:32:19,801] Trial 690 pruned.
# [I 2025-02-25 16:32:19,883] Trial 691 pruned.
# [I 2025-02-25 16:32:20,037] Trial 692 pruned.
# [I 2025-02-25 16:32:20,148] Trial 693 pruned.
# [I 2025-02-25 16:32:20,253] Trial 694 pruned.
# [I 2025-02-25 16:32:20,369] Trial 695 pruned.
# [I 2025-02-25 16:32:20,523] Trial 696 pruned.
# [I 2025-02-25 16:32:20,706] Trial 697 pruned.
# [I 2025-02-25 16:32:20,990] Trial 698 pruned.
# [I 2025-02-25 16:32:21,103] Trial 699 pruned.
# [I 2025-02-25 16:32:21,212] Trial 700 pruned.
# [I 2025-02-25 16:32:21,331] Trial 701 pruned.
# [I 2025-02-25 16:32:21,459] Trial 702 pruned.
# [I 2025-02-25 16:32:21,592] Trial 703 pruned.
# [I 2025-02-25 16:32:21,775] Trial 704 pruned.
# [I 2025-02-25 16:32:21,880] Trial 705 pruned.
# [I 2025-02-25 16:32:21,994] Trial 706 pruned.
# [I 2025-02-25 16:32:22,104] Trial 707 pruned.
# [I 2025-02-25 16:32:22,208] Trial 708 pruned.
# [I 2025-02-25 16:32:22,311] Trial 709 pruned.
# [I 2025-02-25 16:32:22,428] Trial 710 pruned.
# [I 2025-02-25 16:32:22,542] Trial 711 pruned.
# [I 2025-02-25 16:32:22,653] Trial 712 pruned.
# [I 2025-02-25 16:32:22,738] Trial 713 pruned.
# [I 2025-02-25 16:32:22,866] Trial 714 pruned.
# [I 2025-02-25 16:32:22,984] Trial 715 pruned.
# [I 2025-02-25 16:32:23,122] Trial 716 pruned.
# [I 2025-02-25 16:32:23,224] Trial 717 pruned.
# [I 2025-02-25 16:32:23,339] Trial 718 pruned.
# [I 2025-02-25 16:32:23,505] Trial 719 pruned.
# [I 2025-02-25 16:32:27,784] Trial 720 finished with value: 0.04388318280689418 and parameters: {'lr': 0.27754262788260853, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8856789633477723}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:27,871] Trial 721 pruned.
# [I 2025-02-25 16:32:27,970] Trial 722 pruned.
# [I 2025-02-25 16:32:28,096] Trial 723 pruned.
# [I 2025-02-25 16:32:28,199] Trial 724 pruned.
# [I 2025-02-25 16:32:28,301] Trial 725 pruned.
# [I 2025-02-25 16:32:28,394] Trial 726 pruned.
# [I 2025-02-25 16:32:28,498] Trial 727 pruned.
# [I 2025-02-25 16:32:28,610] Trial 728 pruned.
# [I 2025-02-25 16:32:28,711] Trial 729 pruned.
# [I 2025-02-25 16:32:28,817] Trial 730 pruned.
# [I 2025-02-25 16:32:28,947] Trial 731 pruned.
# [I 2025-02-25 16:32:29,057] Trial 732 pruned.
# [I 2025-02-25 16:32:29,189] Trial 733 pruned.
# [I 2025-02-25 16:32:29,305] Trial 734 pruned.
# [I 2025-02-25 16:32:29,435] Trial 735 pruned.
# [I 2025-02-25 16:32:29,527] Trial 736 pruned.
# [I 2025-02-25 16:32:29,636] Trial 737 pruned.
# [I 2025-02-25 16:32:29,753] Trial 738 pruned.
# [I 2025-02-25 16:32:29,862] Trial 739 pruned.
# [I 2025-02-25 16:32:29,985] Trial 740 pruned.
# [I 2025-02-25 16:32:30,109] Trial 741 pruned.
# [I 2025-02-25 16:32:30,275] Trial 742 pruned.
# [I 2025-02-25 16:32:30,383] Trial 743 pruned.
# [I 2025-02-25 16:32:30,496] Trial 744 pruned.
# [I 2025-02-25 16:32:30,618] Trial 745 pruned.
# [I 2025-02-25 16:32:30,730] Trial 746 pruned.
# [I 2025-02-25 16:32:30,850] Trial 747 pruned.
# [I 2025-02-25 16:32:30,966] Trial 748 pruned.
# [I 2025-02-25 16:32:31,103] Trial 749 pruned.
# [I 2025-02-25 16:32:31,303] Trial 750 pruned.
# [I 2025-02-25 16:32:31,475] Trial 751 pruned.
# [I 2025-02-25 16:32:31,583] Trial 752 pruned.
# [I 2025-02-25 16:32:31,714] Trial 753 pruned.
# [I 2025-02-25 16:32:31,853] Trial 754 pruned.
# [I 2025-02-25 16:32:31,964] Trial 755 pruned.
# [I 2025-02-25 16:32:32,090] Trial 756 pruned.
# [I 2025-02-25 16:32:32,182] Trial 757 pruned.
# [I 2025-02-25 16:32:32,323] Trial 758 pruned.
# [I 2025-02-25 16:32:32,456] Trial 759 pruned.
# [I 2025-02-25 16:32:36,305] Trial 760 finished with value: 0.04861659440211952 and parameters: {'lr': 0.004132999083457315, 'batch_size': 32, 'step_size': 19, 'gamma': 0.8127780571776109}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:36,422] Trial 761 pruned.
# [I 2025-02-25 16:32:36,535] Trial 762 pruned.
# [I 2025-02-25 16:32:36,789] Trial 763 pruned.
# [I 2025-02-25 16:32:36,916] Trial 764 pruned.
# [I 2025-02-25 16:32:37,106] Trial 765 pruned.
# [I 2025-02-25 16:32:37,304] Trial 766 pruned.
# [I 2025-02-25 16:32:37,423] Trial 767 pruned.
# [I 2025-02-25 16:32:37,542] Trial 768 pruned.
# [I 2025-02-25 16:32:37,649] Trial 769 pruned.
# [I 2025-02-25 16:32:37,761] Trial 770 pruned.
# [I 2025-02-25 16:32:37,895] Trial 771 pruned.
# [I 2025-02-25 16:32:38,003] Trial 772 pruned.
# [I 2025-02-25 16:32:38,140] Trial 773 pruned.
# [I 2025-02-25 16:32:38,257] Trial 774 pruned.
# [I 2025-02-25 16:32:41,947] Trial 775 finished with value: 0.03645699785556644 and parameters: {'lr': 0.0035912669723831806, 'batch_size': 32, 'step_size': 19, 'gamma': 0.8563886614075927}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:42,057] Trial 776 pruned.
# [I 2025-02-25 16:32:42,180] Trial 777 pruned.
# [I 2025-02-25 16:32:42,290] Trial 778 pruned.
# [I 2025-02-25 16:32:42,403] Trial 779 pruned.
# [I 2025-02-25 16:32:42,512] Trial 780 pruned.
# [I 2025-02-25 16:32:42,627] Trial 781 pruned.
# [I 2025-02-25 16:32:42,724] Trial 782 pruned.
# [I 2025-02-25 16:32:42,904] Trial 783 pruned.
# [I 2025-02-25 16:32:43,019] Trial 784 pruned.
# [I 2025-02-25 16:32:43,139] Trial 785 pruned.
# [I 2025-02-25 16:32:43,278] Trial 786 pruned.
# [I 2025-02-25 16:32:43,462] Trial 787 pruned.
# [I 2025-02-25 16:32:43,612] Trial 788 pruned.
# [I 2025-02-25 16:32:43,821] Trial 789 pruned.
# [I 2025-02-25 16:32:43,930] Trial 790 pruned.
# [I 2025-02-25 16:32:44,139] Trial 791 pruned.
# [I 2025-02-25 16:32:44,320] Trial 792 pruned.
# [I 2025-02-25 16:32:44,432] Trial 793 pruned.
# [I 2025-02-25 16:32:44,562] Trial 794 pruned.
# [I 2025-02-25 16:32:44,680] Trial 795 pruned.
# [I 2025-02-25 16:32:44,812] Trial 796 pruned.
# [I 2025-02-25 16:32:44,925] Trial 797 pruned.
# [I 2025-02-25 16:32:45,052] Trial 798 pruned.
# [I 2025-02-25 16:32:45,163] Trial 799 pruned.
# [I 2025-02-25 16:32:45,367] Trial 800 pruned.
# [I 2025-02-25 16:32:45,483] Trial 801 pruned.
# [I 2025-02-25 16:32:45,574] Trial 802 pruned.
# [I 2025-02-25 16:32:45,686] Trial 803 pruned.
# [I 2025-02-25 16:32:45,814] Trial 804 pruned.
# [I 2025-02-25 16:32:45,936] Trial 805 pruned.
# [I 2025-02-25 16:32:46,047] Trial 806 pruned.
# [I 2025-02-25 16:32:46,164] Trial 807 pruned.
# [I 2025-02-25 16:32:46,303] Trial 808 pruned.
# [I 2025-02-25 16:32:46,480] Trial 809 pruned.
# [I 2025-02-25 16:32:46,605] Trial 810 pruned.
# [I 2025-02-25 16:32:51,079] Trial 811 finished with value: 0.04343967093882384 and parameters: {'lr': 0.4588498392949022, 'batch_size': 32, 'step_size': 8, 'gamma': 0.8114547423576732}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:51,192] Trial 812 pruned.
# [I 2025-02-25 16:32:51,302] Trial 813 pruned.
# [I 2025-02-25 16:32:51,439] Trial 814 pruned.
# [I 2025-02-25 16:32:51,553] Trial 815 pruned.
# [I 2025-02-25 16:32:51,762] Trial 816 pruned.
# [I 2025-02-25 16:32:51,880] Trial 817 pruned.
# [I 2025-02-25 16:32:51,999] Trial 818 pruned.
# [I 2025-02-25 16:32:52,119] Trial 819 pruned.
# [I 2025-02-25 16:32:52,341] Trial 820 pruned.
# [I 2025-02-25 16:32:52,448] Trial 821 pruned.
# [I 2025-02-25 16:32:52,571] Trial 822 pruned.
# [I 2025-02-25 16:32:52,708] Trial 823 pruned.
# [I 2025-02-25 16:32:52,795] Trial 824 pruned.
# [I 2025-02-25 16:32:52,910] Trial 825 pruned.
# [I 2025-02-25 16:32:53,043] Trial 826 pruned.
# [I 2025-02-25 16:32:53,159] Trial 827 pruned.
# [I 2025-02-25 16:32:53,286] Trial 828 pruned.
# [I 2025-02-25 16:32:53,485] Trial 829 pruned.
# [I 2025-02-25 16:32:53,624] Trial 830 pruned.
# [I 2025-02-25 16:32:53,750] Trial 831 pruned.
# [I 2025-02-25 16:32:53,959] Trial 832 pruned.
# [I 2025-02-25 16:32:54,182] Trial 833 pruned.
# [I 2025-02-25 16:32:54,312] Trial 834 pruned.
# [I 2025-02-25 16:32:54,434] Trial 835 pruned.
# [I 2025-02-25 16:32:54,589] Trial 836 pruned.
# [I 2025-02-25 16:32:54,717] Trial 837 pruned.
# [I 2025-02-25 16:32:54,851] Trial 838 pruned.
# [I 2025-02-25 16:32:54,962] Trial 839 pruned.
# [I 2025-02-25 16:32:55,102] Trial 840 pruned.
# [I 2025-02-25 16:32:55,223] Trial 841 pruned.
# [I 2025-02-25 16:32:55,335] Trial 842 pruned.
# [I 2025-02-25 16:32:55,444] Trial 843 pruned.
# [I 2025-02-25 16:32:55,589] Trial 844 pruned.
# [I 2025-02-25 16:32:55,710] Trial 845 pruned.
# [I 2025-02-25 16:32:55,827] Trial 846 pruned.
# [I 2025-02-25 16:32:55,916] Trial 847 pruned.
# [I 2025-02-25 16:32:59,601] Trial 848 finished with value: 0.045498661464080215 and parameters: {'lr': 0.006407359504698232, 'batch_size': 32, 'step_size': 20, 'gamma': 0.799199631071486}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:32:59,719] Trial 849 pruned.
# [I 2025-02-25 16:32:59,829] Trial 850 pruned.
# [I 2025-02-25 16:32:59,949] Trial 851 pruned.
# [I 2025-02-25 16:33:00,090] Trial 852 pruned.
# [I 2025-02-25 16:33:00,241] Trial 853 pruned.
# [I 2025-02-25 16:33:00,365] Trial 854 pruned.
# [I 2025-02-25 16:33:00,531] Trial 855 pruned.
# [I 2025-02-25 16:33:00,654] Trial 856 pruned.
# [I 2025-02-25 16:33:00,778] Trial 857 pruned.
# [I 2025-02-25 16:33:00,910] Trial 858 pruned.
# [I 2025-02-25 16:33:01,055] Trial 859 pruned.
# [I 2025-02-25 16:33:01,167] Trial 860 pruned.
# [I 2025-02-25 16:33:01,273] Trial 861 pruned.
# [I 2025-02-25 16:33:01,383] Trial 862 pruned.
# [I 2025-02-25 16:33:01,543] Trial 863 pruned.
# [I 2025-02-25 16:33:01,686] Trial 864 pruned.
# [I 2025-02-25 16:33:01,802] Trial 865 pruned.
# [I 2025-02-25 16:33:01,913] Trial 866 pruned.
# [I 2025-02-25 16:33:02,045] Trial 867 pruned.
# [I 2025-02-25 16:33:02,157] Trial 868 pruned.
# [I 2025-02-25 16:33:02,242] Trial 869 pruned.
# [I 2025-02-25 16:33:02,351] Trial 870 pruned.
# [I 2025-02-25 16:33:02,511] Trial 871 pruned.
# [I 2025-02-25 16:33:02,623] Trial 872 pruned.
# [I 2025-02-25 16:33:02,805] Trial 873 pruned.
# [I 2025-02-25 16:33:02,919] Trial 874 pruned.
# [I 2025-02-25 16:33:03,072] Trial 875 pruned.
# [I 2025-02-25 16:33:03,229] Trial 876 pruned.
# [I 2025-02-25 16:33:03,338] Trial 877 pruned.
# [I 2025-02-25 16:33:03,467] Trial 878 pruned.
# [I 2025-02-25 16:33:03,575] Trial 879 pruned.
# [I 2025-02-25 16:33:03,679] Trial 880 pruned.
# [I 2025-02-25 16:33:03,895] Trial 881 pruned.
# [I 2025-02-25 16:33:04,005] Trial 882 pruned.
# [I 2025-02-25 16:33:04,122] Trial 883 pruned.
# [I 2025-02-25 16:33:04,238] Trial 884 pruned.
# [I 2025-02-25 16:33:04,352] Trial 885 pruned.
# [I 2025-02-25 16:33:04,470] Trial 886 pruned.
# [I 2025-02-25 16:33:04,616] Trial 887 pruned.
# [I 2025-02-25 16:33:05,101] Trial 888 pruned.
# [I 2025-02-25 16:33:05,210] Trial 889 pruned.
# [I 2025-02-25 16:33:05,336] Trial 890 pruned.
# [I 2025-02-25 16:33:05,443] Trial 891 pruned.
# [I 2025-02-25 16:33:05,533] Trial 892 pruned.
# [I 2025-02-25 16:33:05,651] Trial 893 pruned.
# [I 2025-02-25 16:33:05,766] Trial 894 pruned.
# [I 2025-02-25 16:33:05,897] Trial 895 pruned.
# [I 2025-02-25 16:33:06,027] Trial 896 pruned.
# [I 2025-02-25 16:33:06,146] Trial 897 pruned.
# [I 2025-02-25 16:33:06,306] Trial 898 pruned.
# [I 2025-02-25 16:33:06,418] Trial 899 pruned.
# [I 2025-02-25 16:33:06,522] Trial 900 pruned.
# [I 2025-02-25 16:33:06,666] Trial 901 pruned.
# [I 2025-02-25 16:33:06,779] Trial 902 pruned.
# [I 2025-02-25 16:33:06,888] Trial 903 pruned.
# [I 2025-02-25 16:33:07,009] Trial 904 pruned.
# [I 2025-02-25 16:33:07,240] Trial 905 pruned.
# [I 2025-02-25 16:33:07,371] Trial 906 pruned.
# [I 2025-02-25 16:33:07,481] Trial 907 pruned.
# [I 2025-02-25 16:33:11,191] Trial 908 finished with value: 0.04533346899552271 and parameters: {'lr': 0.007539178135813083, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8520454709173445}. Best is trial 589 with value: 0.03636084566824138.
# [I 2025-02-25 16:33:11,300] Trial 909 pruned.
# [I 2025-02-25 16:33:11,411] Trial 910 pruned.
# [I 2025-02-25 16:33:11,545] Trial 911 pruned.
# [I 2025-02-25 16:33:11,739] Trial 912 pruned.
# [I 2025-02-25 16:33:11,867] Trial 913 pruned.
# [I 2025-02-25 16:33:11,960] Trial 914 pruned.
# [I 2025-02-25 16:33:12,088] Trial 915 pruned.
# [I 2025-02-25 16:33:12,221] Trial 916 pruned.
# [I 2025-02-25 16:33:12,361] Trial 917 pruned.
# [I 2025-02-25 16:33:12,481] Trial 918 pruned.
# [I 2025-02-25 16:33:12,671] Trial 919 pruned.
# [I 2025-02-25 16:33:12,778] Trial 920 pruned.
# [I 2025-02-25 16:33:12,929] Trial 921 pruned.
# [I 2025-02-25 16:33:13,050] Trial 922 pruned.
# [I 2025-02-25 16:33:13,168] Trial 923 pruned.
# [I 2025-02-25 16:33:13,290] Trial 924 pruned.
# [I 2025-02-25 16:33:13,574] Trial 925 pruned.
# [I 2025-02-25 16:33:13,744] Trial 926 pruned.
# [I 2025-02-25 16:33:13,851] Trial 927 pruned.
# [I 2025-02-25 16:33:17,485] Trial 928 finished with value: 0.03588898366433568 and parameters: {'lr': 0.008953359354560458, 'batch_size': 32, 'step_size': 20, 'gamma': 0.8284944216939796}. Best is trial 928 with value: 0.03588898366433568.
# [I 2025-02-25 16:33:17,597] Trial 929 pruned.
# [I 2025-02-25 16:33:17,703] Trial 930 pruned.
# [I 2025-02-25 16:33:17,855] Trial 931 pruned.
# [I 2025-02-25 16:33:17,976] Trial 932 pruned.
# [I 2025-02-25 16:33:18,107] Trial 933 pruned.
# [I 2025-02-25 16:33:18,213] Trial 934 pruned.
# [I 2025-02-25 16:33:18,403] Trial 935 pruned.
# [I 2025-02-25 16:33:18,498] Trial 936 pruned.
# [I 2025-02-25 16:33:18,627] Trial 937 pruned.
# [I 2025-02-25 16:33:18,755] Trial 938 pruned.
# [I 2025-02-25 16:33:18,890] Trial 939 pruned.
# [I 2025-02-25 16:33:19,008] Trial 940 pruned.
# [I 2025-02-25 16:33:19,147] Trial 941 pruned.
# [I 2025-02-25 16:33:19,277] Trial 942 pruned.
# [I 2025-02-25 16:33:19,406] Trial 943 pruned.
# [I 2025-02-25 16:33:19,584] Trial 944 pruned.
# [I 2025-02-25 16:33:19,693] Trial 945 pruned.
# [I 2025-02-25 16:33:19,803] Trial 946 pruned.
# [I 2025-02-25 16:33:19,949] Trial 947 pruned.
# [I 2025-02-25 16:33:23,587] Trial 948 finished with value: 0.050309016020037234 and parameters: {'lr': 0.010729663076098378, 'batch_size': 32, 'step_size': 20, 'gamma': 0.6579422956268067}. Best is trial 928 with value: 0.03588898366433568.
# [I 2025-02-25 16:33:23,697] Trial 949 pruned.
# [I 2025-02-25 16:33:23,819] Trial 950 pruned.
# [I 2025-02-25 16:33:23,946] Trial 951 pruned.
# [I 2025-02-25 16:33:24,052] Trial 952 pruned.
# [I 2025-02-25 16:33:24,167] Trial 953 pruned.
# [I 2025-02-25 16:33:24,285] Trial 954 pruned.
# [I 2025-02-25 16:33:24,399] Trial 955 pruned.
# [I 2025-02-25 16:33:24,516] Trial 956 pruned.
# [I 2025-02-25 16:33:24,627] Trial 957 pruned.
# [I 2025-02-25 16:33:24,741] Trial 958 pruned.
# [I 2025-02-25 16:33:24,830] Trial 959 pruned.
# [I 2025-02-25 16:33:24,955] Trial 960 pruned.
# [I 2025-02-25 16:33:25,062] Trial 961 pruned.
# [I 2025-02-25 16:33:25,535] Trial 962 pruned.
# [I 2025-02-25 16:33:25,654] Trial 963 pruned.
# [I 2025-02-25 16:33:25,776] Trial 964 pruned.
# [I 2025-02-25 16:33:25,889] Trial 965 pruned.
# [I 2025-02-25 16:33:26,105] Trial 966 pruned.
# [I 2025-02-25 16:33:26,310] Trial 967 pruned.
# [I 2025-02-25 16:33:26,524] Trial 968 pruned.
# [I 2025-02-25 16:33:26,659] Trial 969 pruned.
# [I 2025-02-25 16:33:26,775] Trial 970 pruned.
# [I 2025-02-25 16:33:26,891] Trial 971 pruned.
# [I 2025-02-25 16:33:27,013] Trial 972 pruned.
# [I 2025-02-25 16:33:27,132] Trial 973 pruned.
# [I 2025-02-25 16:33:27,255] Trial 974 pruned.
# [I 2025-02-25 16:33:27,385] Trial 975 pruned.
# [I 2025-02-25 16:33:27,511] Trial 976 pruned.
# [I 2025-02-25 16:33:27,644] Trial 977 pruned.
# [I 2025-02-25 16:33:27,838] Trial 978 pruned.
# [I 2025-02-25 16:33:27,969] Trial 979 pruned.
# [I 2025-02-25 16:33:28,070] Trial 980 pruned.
# [I 2025-02-25 16:33:28,193] Trial 981 pruned.
# [I 2025-02-25 16:33:28,316] Trial 982 pruned.
# [I 2025-02-25 16:33:28,434] Trial 983 pruned.
# [I 2025-02-25 16:33:28,546] Trial 984 pruned.
# [I 2025-02-25 16:33:28,678] Trial 985 pruned.
# [I 2025-02-25 16:33:28,790] Trial 986 pruned.
# [I 2025-02-25 16:33:28,957] Trial 987 pruned.
# [I 2025-02-25 16:33:29,057] Trial 988 pruned.
# [I 2025-02-25 16:33:29,158] Trial 989 pruned.
# [I 2025-02-25 16:33:29,255] Trial 990 pruned.
# [I 2025-02-25 16:33:29,388] Trial 991 pruned.
# [I 2025-02-25 16:33:29,500] Trial 992 pruned.
# [I 2025-02-25 16:33:29,619] Trial 993 pruned.
# [I 2025-02-25 16:33:29,741] Trial 994 pruned.
# [I 2025-02-25 16:33:29,908] Trial 995 pruned.
# [I 2025-02-25 16:33:30,111] Trial 996 pruned.
# [I 2025-02-25 16:33:30,225] Trial 997 pruned.
# [I 2025-02-25 16:33:30,344] Trial 998 pruned.
# [I 2025-02-25 16:33:30,469] Trial 999 pruned.
# Stage 1 (Training hyperparameters) Best trial:
#   lr: 0.008953359354560458
#   batch_size: 32
#   step_size: 20
#   gamma: 0.8284944216939796

# %% [markdown]
# ### Neural Architecture Search (NAS) for Multi-Layer Perceptron (MLP)

# %%
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, output_dim, dropout_rate):
        super(MLP, self).__init__()
        layers = []
        last_dim = input_dim
        for h in hidden_sizes:
            layers.append(nn.Linear(last_dim, h))
            layers.append(nn.ReLU())
            layers.append(nn.BatchNorm1d(h))
            layers.append(nn.Dropout(dropout_rate))
            last_dim = h
        layers.append(nn.Linear(last_dim, output_dim))
        layers.append(nn.Sigmoid())
        self.net = nn.Sequential(*layers)
        
    def forward(self, x):
        return self.net(x)
    
    
best_train_params = study_train.best_trial.params

#######################################
# Stage 2: Optimize architecture, using fixed training hyperparameters from Stage 1
#######################################
def objective_arch(trial):
    # Use the best training hyperparameters from stage 1
    lr = best_train_params['lr']
    batch_size = best_train_params['batch_size']
    
    step_size = best_train_params['step_size']
    gamma = best_train_params['gamma']
    
    # Now, search for architecture: let the number of hidden layers vary (1 to 4)
    num_layers = trial.suggest_int('num_layers', 1, 3)
    dropout_rate = trial.suggest_float('dropout_rate', 0.0, 0.3, step=0.1)
    hidden_sizes = []
    for i in range(num_layers):
        h = trial.suggest_int(f'hidden_size_{i}', 100, 5000, step=20)
        hidden_sizes.append(h)
        
    # Create DataLoaders (reuse same datasets)
    train_set = Data.TensorDataset(x_train_encode, y_train)
    val_set   = Data.TensorDataset(x_val_encode, y_val)
    train_loader = Data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
    val_loader   = Data.DataLoader(val_set, batch_size=batch_size, shuffle=False)
    
    # Build network with the candidate architecture
    net = MLP(ndim, hidden_sizes, 1, dropout_rate)
    loss_func = nn.BCELoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
    
    num_epochs = 50  # or use early stopping to accelerate
    best_val_loss = float('inf')
    for epoch in range(num_epochs):
        net.train()
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = loss_func(outputs, targets)
            loss.backward()
            optimizer.step()
            scheduler.step()
        net.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                outputs = net(inputs)
                loss = loss_func(outputs, targets)
                val_loss += loss.item()
        val_loss /= len(val_loader)
        
        trial.report(val_loss, epoch)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
        if val_loss < best_val_loss:
            best_val_loss = val_loss

    return best_val_loss

# Run Stage 2 optimization
study_arch = optuna.create_study(direction="minimize")
study_arch.optimize(objective_arch, n_trials=500)
print("Stage 2 (Architecture search) Best trial:")
for key, value in study_arch.best_trial.params.items():
    print(f"  {key}: {value}")

# The final best configuration is a combination of Stage 1 and Stage 2:
final_best_config = {**best_train_params, **study_arch.best_trial.params}
print("Final best configuration:")
for key, value in final_best_config.items():
    print(f"  {key}: {value}")
# Out:
# [I 2025-02-25 16:56:13,499] A new study created in memory with name: no-name-89b909b8-3efc-4a18-9bb0-db2a0aed82d4
# [I 2025-02-25 16:56:15,821] Trial 0 finished with value: 0.019901636868908668 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 2420}. Best is trial 0 with value: 0.019901636868908668.
# [I 2025-02-25 16:56:42,610] Trial 1 finished with value: 0.03148012325982563 and parameters: {'num_layers': 2, 'dropout_rate': 0.1, 'hidden_size_0': 2460, 'hidden_size_1': 3140}. Best is trial 0 with value: 0.019901636868908668.
# [I 2025-02-25 16:56:44,827] Trial 2 finished with value: 0.011522357182911969 and parameters: {'num_layers': 1, 'dropout_rate': 0.0, 'hidden_size_0': 4140}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:57:18,115] Trial 3 finished with value: 0.03310963294370595 and parameters: {'num_layers': 2, 'dropout_rate': 0.3, 'hidden_size_0': 2980, 'hidden_size_1': 2840}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:58:26,727] Trial 4 finished with value: 0.024879644259044653 and parameters: {'num_layers': 2, 'dropout_rate': 0.3, 'hidden_size_0': 4300, 'hidden_size_1': 4900}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:58:27,923] Trial 5 pruned.
# [I 2025-02-25 16:58:28,037] Trial 6 pruned.
# [I 2025-02-25 16:58:28,096] Trial 7 pruned.
# [I 2025-02-25 16:58:29,776] Trial 8 pruned.
# [I 2025-02-25 16:58:30,874] Trial 9 pruned.
# [I 2025-02-25 16:58:31,320] Trial 10 pruned.
# [I 2025-02-25 16:58:31,565] Trial 11 pruned.
# [I 2025-02-25 16:58:31,688] Trial 12 pruned.
# [I 2025-02-25 16:58:31,917] Trial 13 pruned.
# [I 2025-02-25 16:58:32,557] Trial 14 pruned.
# [I 2025-02-25 16:58:32,637] Trial 15 pruned.
# [I 2025-02-25 16:58:32,746] Trial 16 pruned.
# [I 2025-02-25 16:58:33,165] Trial 17 pruned.
# [I 2025-02-25 16:58:34,754] Trial 18 finished with value: 0.030046093224228798 and parameters: {'num_layers': 1, 'dropout_rate': 0.0, 'hidden_size_0': 1600}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:58:34,934] Trial 19 pruned.
# [I 2025-02-25 16:58:37,156] Trial 20 finished with value: 0.02359777509299945 and parameters: {'num_layers': 1, 'dropout_rate': 0.0, 'hidden_size_0': 4180}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:58:37,225] Trial 21 pruned.
# [I 2025-02-25 16:58:37,487] Trial 22 pruned.
# [I 2025-02-25 16:58:37,538] Trial 23 pruned.
# [I 2025-02-25 16:58:37,601] Trial 24 pruned.
# [I 2025-02-25 16:58:38,929] Trial 25 pruned.
# [I 2025-02-25 16:58:38,999] Trial 26 pruned.
# [I 2025-02-25 16:58:39,273] Trial 27 pruned.
# [I 2025-02-25 16:58:39,378] Trial 28 pruned.
# [I 2025-02-25 16:58:40,154] Trial 29 pruned.
# [I 2025-02-25 16:58:40,250] Trial 30 pruned.
# [I 2025-02-25 16:58:48,482] Trial 31 pruned.
# [I 2025-02-25 16:58:49,725] Trial 32 pruned.
# [I 2025-02-25 16:58:51,357] Trial 33 pruned.
# [I 2025-02-25 16:58:52,458] Trial 34 pruned.
# [I 2025-02-25 16:58:52,548] Trial 35 pruned.
# [I 2025-02-25 16:58:53,482] Trial 36 pruned.
# [I 2025-02-25 16:58:55,623] Trial 37 finished with value: 0.02229906514042794 and parameters: {'num_layers': 1, 'dropout_rate': 0.3, 'hidden_size_0': 3560}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:58:55,687] Trial 38 pruned.
# [I 2025-02-25 16:58:55,744] Trial 39 pruned.
# [I 2025-02-25 16:58:55,857] Trial 40 pruned.
# [I 2025-02-25 16:58:55,937] Trial 41 pruned.
# [I 2025-02-25 16:58:56,009] Trial 42 pruned.
# [I 2025-02-25 16:58:56,093] Trial 43 pruned.
# [I 2025-02-25 16:58:57,728] Trial 44 pruned.
# [I 2025-02-25 16:58:57,792] Trial 45 pruned.
# [I 2025-02-25 16:58:58,610] Trial 46 pruned.
# [I 2025-02-25 16:58:58,670] Trial 47 pruned.
# [I 2025-02-25 16:58:58,745] Trial 48 pruned.
# [I 2025-02-25 16:58:58,808] Trial 49 pruned.
# [I 2025-02-25 16:59:27,093] Trial 50 finished with value: 0.032693141283857585 and parameters: {'num_layers': 3, 'dropout_rate': 0.0, 'hidden_size_0': 4740, 'hidden_size_1': 1140, 'hidden_size_2': 2380}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:59:27,154] Trial 51 pruned.
# [I 2025-02-25 16:59:28,761] Trial 52 finished with value: 0.025916414354014705 and parameters: {'num_layers': 1, 'dropout_rate': 0.0, 'hidden_size_0': 1620}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:59:28,835] Trial 53 pruned.
# [I 2025-02-25 16:59:28,894] Trial 54 pruned.
# [I 2025-02-25 16:59:30,643] Trial 55 finished with value: 0.02368537413701688 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1540}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:59:30,692] Trial 56 pruned.
# [I 2025-02-25 16:59:30,995] Trial 57 pruned.
# [I 2025-02-25 16:59:31,046] Trial 58 pruned.
# [I 2025-02-25 16:59:31,265] Trial 59 pruned.
# [I 2025-02-25 16:59:31,329] Trial 60 pruned.
# [I 2025-02-25 16:59:31,423] Trial 61 pruned.
# [I 2025-02-25 16:59:31,475] Trial 62 pruned.
# [I 2025-02-25 16:59:31,538] Trial 63 pruned.
# [I 2025-02-25 16:59:31,630] Trial 64 pruned.
# [I 2025-02-25 16:59:31,677] Trial 65 pruned.
# [I 2025-02-25 16:59:31,742] Trial 66 pruned.
# [I 2025-02-25 16:59:32,352] Trial 67 pruned.
# [I 2025-02-25 16:59:32,474] Trial 68 pruned.
# [I 2025-02-25 16:59:32,541] Trial 69 pruned.
# [I 2025-02-25 16:59:32,638] Trial 70 pruned.
# [I 2025-02-25 16:59:32,719] Trial 71 pruned.
# [I 2025-02-25 16:59:32,774] Trial 72 pruned.
# [I 2025-02-25 16:59:34,506] Trial 73 finished with value: 0.02837788263616403 and parameters: {'num_layers': 1, 'dropout_rate': 0.0, 'hidden_size_0': 2420}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:59:34,593] Trial 74 pruned.
# [I 2025-02-25 16:59:34,655] Trial 75 pruned.
# [I 2025-02-25 16:59:34,717] Trial 76 pruned.
# [I 2025-02-25 16:59:36,476] Trial 77 finished with value: 0.01547656397761174 and parameters: {'num_layers': 1, 'dropout_rate': 0.3, 'hidden_size_0': 2320}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:59:37,000] Trial 78 pruned.
# [I 2025-02-25 16:59:37,093] Trial 79 pruned.
# [I 2025-02-25 16:59:37,158] Trial 80 pruned.
# [I 2025-02-25 16:59:37,258] Trial 81 pruned.
# [I 2025-02-25 16:59:37,318] Trial 82 pruned.
# [I 2025-02-25 16:59:37,381] Trial 83 pruned.
# [I 2025-02-25 16:59:37,498] Trial 84 pruned.
# [I 2025-02-25 16:59:37,609] Trial 85 pruned.
# [I 2025-02-25 16:59:37,705] Trial 86 pruned.
# [I 2025-02-25 16:59:38,408] Trial 87 pruned.
# [I 2025-02-25 16:59:38,490] Trial 88 pruned.
# [I 2025-02-25 16:59:38,545] Trial 89 pruned.
# [I 2025-02-25 16:59:40,241] Trial 90 pruned.
# [I 2025-02-25 16:59:40,296] Trial 91 pruned.
# [I 2025-02-25 16:59:40,375] Trial 92 pruned.
# [I 2025-02-25 16:59:40,465] Trial 93 pruned.
# [I 2025-02-25 16:59:40,588] Trial 94 pruned.
# [I 2025-02-25 16:59:42,305] Trial 95 finished with value: 0.03116136019525584 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1560}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:59:42,353] Trial 96 pruned.
# [I 2025-02-25 16:59:42,563] Trial 97 pruned.
# [I 2025-02-25 16:59:42,638] Trial 98 pruned.
# [I 2025-02-25 16:59:42,757] Trial 99 pruned.
# [I 2025-02-25 16:59:42,846] Trial 100 pruned.
# [I 2025-02-25 16:59:42,905] Trial 101 pruned.
# [I 2025-02-25 16:59:42,972] Trial 102 pruned.
# [I 2025-02-25 16:59:43,054] Trial 103 pruned.
# [I 2025-02-25 16:59:43,138] Trial 104 pruned.
# [I 2025-02-25 16:59:43,249] Trial 105 pruned.
# [I 2025-02-25 16:59:43,330] Trial 106 pruned.
# [I 2025-02-25 16:59:43,414] Trial 107 pruned.
# [I 2025-02-25 16:59:43,773] Trial 108 pruned.
# [I 2025-02-25 16:59:43,849] Trial 109 pruned.
# [I 2025-02-25 16:59:43,956] Trial 110 pruned.
# [I 2025-02-25 16:59:44,649] Trial 111 pruned.
# [I 2025-02-25 16:59:45,283] Trial 112 pruned.
# [I 2025-02-25 16:59:45,929] Trial 113 pruned.
# [I 2025-02-25 16:59:46,812] Trial 114 pruned.
# [I 2025-02-25 16:59:46,883] Trial 115 pruned.
# [I 2025-02-25 16:59:47,313] Trial 116 pruned.
# [I 2025-02-25 16:59:47,391] Trial 117 pruned.
# [I 2025-02-25 16:59:56,492] Trial 118 finished with value: 0.03913744355668314 and parameters: {'num_layers': 2, 'dropout_rate': 0.2, 'hidden_size_0': 4040, 'hidden_size_1': 540}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 16:59:56,553] Trial 119 pruned.
# [I 2025-02-25 16:59:56,683] Trial 120 pruned.
# [I 2025-02-25 16:59:57,494] Trial 121 pruned.
# [I 2025-02-25 16:59:57,829] Trial 122 pruned.
# [I 2025-02-25 16:59:59,236] Trial 123 pruned.
# [I 2025-02-25 16:59:59,764] Trial 124 pruned.
# [I 2025-02-25 17:00:00,594] Trial 125 pruned.
# [I 2025-02-25 17:00:00,681] Trial 126 pruned.
# [I 2025-02-25 17:00:00,757] Trial 127 pruned.
# [I 2025-02-25 17:00:00,957] Trial 128 pruned.
# [I 2025-02-25 17:00:01,096] Trial 129 pruned.
# [I 2025-02-25 17:00:01,396] Trial 130 pruned.
# [I 2025-02-25 17:00:02,408] Trial 131 pruned.
# [I 2025-02-25 17:00:03,514] Trial 132 pruned.
# [I 2025-02-25 17:00:04,329] Trial 133 pruned.
# [I 2025-02-25 17:00:05,121] Trial 134 pruned.
# [I 2025-02-25 17:00:06,882] Trial 135 pruned.
# [I 2025-02-25 17:00:06,995] Trial 136 pruned.
# [I 2025-02-25 17:00:07,082] Trial 137 pruned.
# [I 2025-02-25 17:00:07,336] Trial 138 pruned.
# [I 2025-02-25 17:00:09,685] Trial 139 pruned.
# [I 2025-02-25 17:00:09,758] Trial 140 pruned.
# [I 2025-02-25 17:00:10,148] Trial 141 pruned.
# [I 2025-02-25 17:00:10,627] Trial 142 pruned.
# [I 2025-02-25 17:00:11,337] Trial 143 pruned.
# [I 2025-02-25 17:00:12,848] Trial 144 pruned.
# [I 2025-02-25 17:00:13,369] Trial 145 pruned.
# [I 2025-02-25 17:00:13,674] Trial 146 pruned.
# [I 2025-02-25 17:00:13,745] Trial 147 pruned.
# [I 2025-02-25 17:00:13,801] Trial 148 pruned.
# [I 2025-02-25 17:00:13,878] Trial 149 pruned.
# [I 2025-02-25 17:00:14,162] Trial 150 pruned.
# [I 2025-02-25 17:00:14,356] Trial 151 pruned.
# [I 2025-02-25 17:00:14,520] Trial 152 pruned.
# [I 2025-02-25 17:00:15,089] Trial 153 pruned.
# [I 2025-02-25 17:00:15,145] Trial 154 pruned.
# [I 2025-02-25 17:00:17,473] Trial 155 pruned.
# [I 2025-02-25 17:00:17,535] Trial 156 pruned.
# [I 2025-02-25 17:00:17,782] Trial 157 pruned.
# [I 2025-02-25 17:00:17,871] Trial 158 pruned.
# [I 2025-02-25 17:00:19,562] Trial 159 finished with value: 0.03125872321733425 and parameters: {'num_layers': 1, 'dropout_rate': 0.0, 'hidden_size_0': 1360}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:00:19,650] Trial 160 pruned.
# [I 2025-02-25 17:00:19,740] Trial 161 pruned.
# [I 2025-02-25 17:00:19,806] Trial 162 pruned.
# [I 2025-02-25 17:00:19,879] Trial 163 pruned.
# [I 2025-02-25 17:00:19,994] Trial 164 pruned.
# [I 2025-02-25 17:00:20,095] Trial 165 pruned.
# [I 2025-02-25 17:00:20,230] Trial 166 pruned.
# [I 2025-02-25 17:00:21,028] Trial 167 pruned.
# [I 2025-02-25 17:00:21,111] Trial 168 pruned.
# [I 2025-02-25 17:00:21,165] Trial 169 pruned.
# [I 2025-02-25 17:00:21,254] Trial 170 pruned.
# [I 2025-02-25 17:00:29,875] Trial 171 finished with value: 0.0323667505508638 and parameters: {'num_layers': 2, 'dropout_rate': 0.3, 'hidden_size_0': 2600, 'hidden_size_1': 920}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:00:30,175] Trial 172 pruned.
# [I 2025-02-25 17:00:31,282] Trial 173 pruned.
# [I 2025-02-25 17:00:32,566] Trial 174 pruned.
# [I 2025-02-25 17:00:33,052] Trial 175 pruned.
# [I 2025-02-25 17:00:33,597] Trial 176 pruned.
# [I 2025-02-25 17:00:33,819] Trial 177 pruned.
# [I 2025-02-25 17:00:34,906] Trial 178 pruned.
# [I 2025-02-25 17:00:35,393] Trial 179 pruned.
# [I 2025-02-25 17:00:35,768] Trial 180 pruned.
# [I 2025-02-25 17:00:36,046] Trial 181 pruned.
# [I 2025-02-25 17:00:36,357] Trial 182 pruned.
# [I 2025-02-25 17:00:37,016] Trial 183 pruned.
# [I 2025-02-25 17:00:37,301] Trial 184 pruned.
# [I 2025-02-25 17:00:37,785] Trial 185 pruned.
# [I 2025-02-25 17:00:37,954] Trial 186 pruned.
# [I 2025-02-25 17:00:38,716] Trial 187 pruned.
# [I 2025-02-25 17:00:38,813] Trial 188 pruned.
# [I 2025-02-25 17:00:38,895] Trial 189 pruned.
# [I 2025-02-25 17:00:38,958] Trial 190 pruned.
# [I 2025-02-25 17:00:39,244] Trial 191 pruned.
# [I 2025-02-25 17:00:39,647] Trial 192 pruned.
# [I 2025-02-25 17:00:39,848] Trial 193 pruned.
# [I 2025-02-25 17:00:40,226] Trial 194 pruned.
# [I 2025-02-25 17:00:40,477] Trial 195 pruned.
# [I 2025-02-25 17:00:40,865] Trial 196 pruned.
# [I 2025-02-25 17:00:41,544] Trial 197 pruned.
# [I 2025-02-25 17:00:41,973] Trial 198 pruned.
# [I 2025-02-25 17:00:42,047] Trial 199 pruned.
# [I 2025-02-25 17:00:42,103] Trial 200 pruned.
# [I 2025-02-25 17:00:42,155] Trial 201 pruned.
# [I 2025-02-25 17:00:42,233] Trial 202 pruned.
# [I 2025-02-25 17:00:42,290] Trial 203 pruned.
# [I 2025-02-25 17:00:42,378] Trial 204 pruned.
# [I 2025-02-25 17:00:42,447] Trial 205 pruned.
# [I 2025-02-25 17:00:42,504] Trial 206 pruned.
# [I 2025-02-25 17:00:43,432] Trial 207 pruned.
# [I 2025-02-25 17:00:43,511] Trial 208 pruned.
# [I 2025-02-25 17:00:43,838] Trial 209 pruned.
# [I 2025-02-25 17:00:43,905] Trial 210 pruned.
# [I 2025-02-25 17:00:43,965] Trial 211 pruned.
# [I 2025-02-25 17:00:44,014] Trial 212 pruned.
# [I 2025-02-25 17:00:44,073] Trial 213 pruned.
# [I 2025-02-25 17:00:44,156] Trial 214 pruned.
# [I 2025-02-25 17:00:44,224] Trial 215 pruned.
# [I 2025-02-25 17:00:44,285] Trial 216 pruned.
# [I 2025-02-25 17:00:44,338] Trial 217 pruned.
# [I 2025-02-25 17:00:45,274] Trial 218 pruned.
# [I 2025-02-25 17:00:46,945] Trial 219 pruned.
# [I 2025-02-25 17:00:47,078] Trial 220 pruned.
# [I 2025-02-25 17:00:48,455] Trial 221 finished with value: 0.030285234114671766 and parameters: {'num_layers': 1, 'dropout_rate': 0.0, 'hidden_size_0': 1500}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:00:48,532] Trial 222 pruned.
# [I 2025-02-25 17:00:48,581] Trial 223 pruned.
# [I 2025-02-25 17:00:48,679] Trial 224 pruned.
# [I 2025-02-25 17:00:48,768] Trial 225 pruned.
# [I 2025-02-25 17:00:48,845] Trial 226 pruned.
# [I 2025-02-25 17:00:49,132] Trial 227 pruned.
# [I 2025-02-25 17:00:49,250] Trial 228 pruned.
# [I 2025-02-25 17:00:49,901] Trial 229 pruned.
# [I 2025-02-25 17:00:49,994] Trial 230 pruned.
# [I 2025-02-25 17:00:50,066] Trial 231 pruned.
# [I 2025-02-25 17:00:50,169] Trial 232 pruned.
# [I 2025-02-25 17:00:50,235] Trial 233 pruned.
# [I 2025-02-25 17:00:50,323] Trial 234 pruned.
# [I 2025-02-25 17:00:50,422] Trial 235 pruned.
# [I 2025-02-25 17:00:51,026] Trial 236 pruned.
# [I 2025-02-25 17:00:52,777] Trial 237 finished with value: 0.04201078014284576 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1240}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:00:52,847] Trial 238 pruned.
# [I 2025-02-25 17:00:52,944] Trial 239 pruned.
# [I 2025-02-25 17:00:53,052] Trial 240 pruned.
# [I 2025-02-25 17:00:53,108] Trial 241 pruned.
# [I 2025-02-25 17:00:53,200] Trial 242 pruned.
# [I 2025-02-25 17:00:53,297] Trial 243 pruned.
# [I 2025-02-25 17:00:53,437] Trial 244 pruned.
# [I 2025-02-25 17:00:55,141] Trial 245 finished with value: 0.030396698517506593 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1460}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:00:56,110] Trial 246 pruned.
# [I 2025-02-25 17:00:57,655] Trial 247 finished with value: 0.03173263131196791 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1440}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:00:57,716] Trial 248 pruned.
# [I 2025-02-25 17:00:59,461] Trial 249 finished with value: 0.03706731885586123 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1420}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:00:59,575] Trial 250 pruned.
# [I 2025-02-25 17:00:59,916] Trial 251 pruned.
# [I 2025-02-25 17:00:59,990] Trial 252 pruned.
# [I 2025-02-25 17:01:00,208] Trial 253 pruned.
# [I 2025-02-25 17:01:00,272] Trial 254 pruned.
# [I 2025-02-25 17:01:00,363] Trial 255 pruned.
# [I 2025-02-25 17:01:00,476] Trial 256 pruned.
# [I 2025-02-25 17:01:00,567] Trial 257 pruned.
# [I 2025-02-25 17:01:02,620] Trial 258 pruned.
# [I 2025-02-25 17:01:09,347] Trial 259 finished with value: 0.03345188291859813 and parameters: {'num_layers': 2, 'dropout_rate': 0.1, 'hidden_size_0': 2560, 'hidden_size_1': 640}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:01:09,555] Trial 260 pruned.
# [I 2025-02-25 17:01:09,627] Trial 261 pruned.
# [I 2025-02-25 17:01:09,688] Trial 262 pruned.
# [I 2025-02-25 17:01:09,749] Trial 263 pruned.
# [I 2025-02-25 17:01:09,999] Trial 264 pruned.
# [I 2025-02-25 17:01:10,067] Trial 265 pruned.
# [I 2025-02-25 17:01:10,131] Trial 266 pruned.
# [I 2025-02-25 17:01:10,759] Trial 267 pruned.
# [I 2025-02-25 17:01:10,947] Trial 268 pruned.
# [I 2025-02-25 17:01:11,006] Trial 269 pruned.
# [I 2025-02-25 17:01:11,527] Trial 270 pruned.
# [I 2025-02-25 17:01:13,253] Trial 271 finished with value: 0.025778445354717405 and parameters: {'num_layers': 1, 'dropout_rate': 0.2, 'hidden_size_0': 1780}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:01:13,332] Trial 272 pruned.
# [I 2025-02-25 17:01:13,411] Trial 273 pruned.
# [I 2025-02-25 17:01:13,519] Trial 274 pruned.
# [I 2025-02-25 17:01:13,597] Trial 275 pruned.
# [I 2025-02-25 17:01:13,654] Trial 276 pruned.
# [I 2025-02-25 17:01:13,763] Trial 277 pruned.
# [I 2025-02-25 17:01:13,871] Trial 278 pruned.
# [I 2025-02-25 17:01:13,958] Trial 279 pruned.
# [I 2025-02-25 17:01:14,586] Trial 280 pruned.
# [I 2025-02-25 17:01:14,649] Trial 281 pruned.
# [I 2025-02-25 17:01:14,711] Trial 282 pruned.
# [I 2025-02-25 17:01:14,928] Trial 283 pruned.
# [I 2025-02-25 17:01:15,009] Trial 284 pruned.
# [I 2025-02-25 17:01:15,092] Trial 285 pruned.
# [I 2025-02-25 17:01:15,318] Trial 286 pruned.
# [I 2025-02-25 17:01:15,420] Trial 287 pruned.
# [I 2025-02-25 17:01:15,488] Trial 288 pruned.
# [I 2025-02-25 17:01:15,576] Trial 289 pruned.
# [I 2025-02-25 17:01:16,864] Trial 290 pruned.
# [I 2025-02-25 17:01:19,091] Trial 291 finished with value: 0.03276132603696169 and parameters: {'num_layers': 1, 'dropout_rate': 0.3, 'hidden_size_0': 1240}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:01:20,669] Trial 292 finished with value: 0.03062094866413645 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1120}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:01:20,767] Trial 293 pruned.
# [I 2025-02-25 17:01:20,855] Trial 294 pruned.
# [I 2025-02-25 17:01:22,468] Trial 295 finished with value: 0.03486151750530553 and parameters: {'num_layers': 1, 'dropout_rate': 0.3, 'hidden_size_0': 1040}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:01:22,549] Trial 296 pruned.
# [I 2025-02-25 17:01:22,643] Trial 297 pruned.
# [I 2025-02-25 17:01:22,733] Trial 298 pruned.
# [I 2025-02-25 17:01:24,434] Trial 299 finished with value: 0.038311132393573644 and parameters: {'num_layers': 1, 'dropout_rate': 0.3, 'hidden_size_0': 1060}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:01:24,521] Trial 300 pruned.
# [I 2025-02-25 17:01:24,610] Trial 301 pruned.
# [I 2025-02-25 17:01:24,661] Trial 302 pruned.
# [I 2025-02-25 17:01:24,752] Trial 303 pruned.
# [I 2025-02-25 17:01:24,834] Trial 304 pruned.
# [I 2025-02-25 17:01:24,934] Trial 305 pruned.
# [I 2025-02-25 17:01:25,032] Trial 306 pruned.
# [I 2025-02-25 17:01:25,108] Trial 307 pruned.
# [I 2025-02-25 17:01:25,163] Trial 308 pruned.
# [I 2025-02-25 17:01:25,229] Trial 309 pruned.
# [I 2025-02-25 17:01:25,297] Trial 310 pruned.
# [I 2025-02-25 17:01:25,380] Trial 311 pruned.
# [I 2025-02-25 17:01:25,449] Trial 312 pruned.
# [I 2025-02-25 17:01:25,530] Trial 313 pruned.
# [I 2025-02-25 17:01:25,594] Trial 314 pruned.
# [I 2025-02-25 17:01:25,656] Trial 315 pruned.
# [I 2025-02-25 17:01:25,741] Trial 316 pruned.
# [I 2025-02-25 17:01:25,804] Trial 317 pruned.
# [I 2025-02-25 17:01:25,863] Trial 318 pruned.
# [I 2025-02-25 17:01:25,946] Trial 319 pruned.
# [I 2025-02-25 17:01:26,011] Trial 320 pruned.
# [I 2025-02-25 17:01:26,071] Trial 321 pruned.
# [I 2025-02-25 17:01:26,129] Trial 322 pruned.
# [I 2025-02-25 17:01:26,220] Trial 323 pruned.
# [I 2025-02-25 17:01:26,272] Trial 324 pruned.
# [I 2025-02-25 17:01:26,348] Trial 325 pruned.
# [I 2025-02-25 17:01:26,448] Trial 326 pruned.
# [I 2025-02-25 17:01:26,510] Trial 327 pruned.
# [I 2025-02-25 17:01:26,575] Trial 328 pruned.
# [I 2025-02-25 17:01:26,655] Trial 329 pruned.
# [I 2025-02-25 17:01:26,733] Trial 330 pruned.
# [I 2025-02-25 17:01:26,819] Trial 331 pruned.
# [I 2025-02-25 17:01:26,899] Trial 332 pruned.
# [I 2025-02-25 17:01:27,013] Trial 333 pruned.
# [I 2025-02-25 17:01:27,108] Trial 334 pruned.
# [I 2025-02-25 17:01:27,168] Trial 335 pruned.
# [I 2025-02-25 17:01:27,231] Trial 336 pruned.
# [I 2025-02-25 17:01:27,315] Trial 337 pruned.
# [I 2025-02-25 17:01:27,375] Trial 338 pruned.
# [I 2025-02-25 17:01:27,479] Trial 339 pruned.
# [I 2025-02-25 17:01:28,736] Trial 340 pruned.
# [I 2025-02-25 17:01:28,820] Trial 341 pruned.
# [I 2025-02-25 17:01:28,891] Trial 342 pruned.
# [I 2025-02-25 17:01:28,983] Trial 343 pruned.
# [I 2025-02-25 17:01:29,716] Trial 344 pruned.
# [I 2025-02-25 17:01:29,798] Trial 345 pruned.
# [I 2025-02-25 17:01:29,902] Trial 346 pruned.
# [I 2025-02-25 17:01:29,965] Trial 347 pruned.
# [I 2025-02-25 17:01:30,047] Trial 348 pruned.
# [I 2025-02-25 17:01:30,828] Trial 349 pruned.
# [I 2025-02-25 17:01:30,925] Trial 350 pruned.
# [I 2025-02-25 17:01:31,001] Trial 351 pruned.
# [I 2025-02-25 17:01:31,110] Trial 352 pruned.
# [I 2025-02-25 17:01:31,475] Trial 353 pruned.
# [I 2025-02-25 17:01:31,539] Trial 354 pruned.
# [I 2025-02-25 17:01:31,596] Trial 355 pruned.
# [I 2025-02-25 17:01:31,688] Trial 356 pruned.
# [I 2025-02-25 17:01:32,115] Trial 357 pruned.
# [I 2025-02-25 17:01:32,208] Trial 358 pruned.
# [I 2025-02-25 17:01:32,265] Trial 359 pruned.
# [I 2025-02-25 17:01:34,004] Trial 360 finished with value: 0.0386434840856964 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1180}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:01:35,120] Trial 361 pruned.
# [I 2025-02-25 17:01:35,180] Trial 362 pruned.
# [I 2025-02-25 17:01:35,274] Trial 363 pruned.
# [I 2025-02-25 17:01:35,338] Trial 364 pruned.
# [I 2025-02-25 17:01:35,430] Trial 365 pruned.
# [I 2025-02-25 17:01:36,688] Trial 366 pruned.
# [I 2025-02-25 17:01:36,753] Trial 367 pruned.
# [I 2025-02-25 17:01:36,845] Trial 368 pruned.
# [I 2025-02-25 17:01:36,931] Trial 369 pruned.
# [I 2025-02-25 17:01:37,320] Trial 370 pruned.
# [I 2025-02-25 17:01:37,387] Trial 371 pruned.
# [I 2025-02-25 17:01:39,179] Trial 372 finished with value: 0.02938748983615369 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1480}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:01:39,294] Trial 373 pruned.
# [I 2025-02-25 17:01:39,408] Trial 374 pruned.
# [I 2025-02-25 17:01:39,784] Trial 375 pruned.
# [I 2025-02-25 17:01:39,856] Trial 376 pruned.
# [I 2025-02-25 17:01:39,936] Trial 377 pruned.
# [I 2025-02-25 17:01:40,017] Trial 378 pruned.
# [I 2025-02-25 17:01:40,396] Trial 379 pruned.
# [I 2025-02-25 17:01:40,481] Trial 380 pruned.
# [I 2025-02-25 17:01:40,580] Trial 381 pruned.
# [I 2025-02-25 17:01:40,644] Trial 382 pruned.
# [I 2025-02-25 17:01:40,722] Trial 383 pruned.
# [I 2025-02-25 17:01:41,058] Trial 384 pruned.
# [I 2025-02-25 17:01:41,165] Trial 385 pruned.
# [I 2025-02-25 17:01:41,223] Trial 386 pruned.
# [I 2025-02-25 17:01:41,307] Trial 387 pruned.
# [I 2025-02-25 17:01:41,526] Trial 388 pruned.
# [I 2025-02-25 17:01:41,596] Trial 389 pruned.
# [I 2025-02-25 17:01:43,446] Trial 390 pruned.
# [I 2025-02-25 17:01:43,516] Trial 391 pruned.
# [I 2025-02-25 17:01:43,609] Trial 392 pruned.
# [I 2025-02-25 17:01:43,682] Trial 393 pruned.
# [I 2025-02-25 17:01:43,980] Trial 394 pruned.
# [I 2025-02-25 17:01:44,043] Trial 395 pruned.
# [I 2025-02-25 17:01:44,103] Trial 396 pruned.
# [I 2025-02-25 17:01:44,179] Trial 397 pruned.
# [I 2025-02-25 17:01:44,543] Trial 398 pruned.
# [I 2025-02-25 17:01:44,629] Trial 399 pruned.
# [I 2025-02-25 17:01:44,690] Trial 400 pruned.
# [I 2025-02-25 17:01:44,769] Trial 401 pruned.
# [I 2025-02-25 17:01:45,795] Trial 402 pruned.
# [I 2025-02-25 17:01:46,631] Trial 403 pruned.
# [I 2025-02-25 17:01:46,707] Trial 404 pruned.
# [I 2025-02-25 17:01:46,806] Trial 405 pruned.
# [I 2025-02-25 17:01:46,878] Trial 406 pruned.
# [I 2025-02-25 17:01:46,984] Trial 407 pruned.
# [I 2025-02-25 17:01:47,058] Trial 408 pruned.
# [I 2025-02-25 17:01:47,368] Trial 409 pruned.
# [I 2025-02-25 17:01:47,424] Trial 410 pruned.
# [I 2025-02-25 17:01:47,522] Trial 411 pruned.
# [I 2025-02-25 17:01:47,586] Trial 412 pruned.
# [I 2025-02-25 17:01:47,997] Trial 413 pruned.
# [I 2025-02-25 17:01:48,077] Trial 414 pruned.
# [I 2025-02-25 17:01:48,158] Trial 415 pruned.
# [I 2025-02-25 17:01:48,224] Trial 416 pruned.
# [I 2025-02-25 17:01:48,310] Trial 417 pruned.
# [I 2025-02-25 17:01:48,372] Trial 418 pruned.
# [I 2025-02-25 17:01:48,924] Trial 419 pruned.
# [I 2025-02-25 17:01:48,997] Trial 420 pruned.
# [I 2025-02-25 17:01:49,055] Trial 421 pruned.
# [I 2025-02-25 17:01:49,122] Trial 422 pruned.
# [I 2025-02-25 17:01:49,640] Trial 423 pruned.
# [I 2025-02-25 17:01:49,707] Trial 424 pruned.
# [I 2025-02-25 17:01:49,775] Trial 425 pruned.
# [I 2025-02-25 17:01:50,401] Trial 426 pruned.
# [I 2025-02-25 17:01:50,545] Trial 427 pruned.
# [I 2025-02-25 17:01:50,642] Trial 428 pruned.
# [I 2025-02-25 17:01:50,724] Trial 429 pruned.
# [I 2025-02-25 17:01:51,731] Trial 430 pruned.
# [I 2025-02-25 17:01:52,458] Trial 431 pruned.
# [I 2025-02-25 17:01:52,550] Trial 432 pruned.
# [I 2025-02-25 17:01:52,634] Trial 433 pruned.
# [I 2025-02-25 17:01:52,744] Trial 434 pruned.
# [I 2025-02-25 17:01:52,820] Trial 435 pruned.
# [I 2025-02-25 17:01:53,038] Trial 436 pruned.
# [I 2025-02-25 17:01:53,148] Trial 437 pruned.
# [I 2025-02-25 17:01:53,221] Trial 438 pruned.
# [I 2025-02-25 17:01:53,297] Trial 439 pruned.
# [I 2025-02-25 17:01:53,365] Trial 440 pruned.
# [I 2025-02-25 17:01:53,659] Trial 441 pruned.
# [I 2025-02-25 17:01:53,741] Trial 442 pruned.
# [I 2025-02-25 17:01:53,858] Trial 443 pruned.
# [I 2025-02-25 17:01:53,942] Trial 444 pruned.
# [I 2025-02-25 17:01:54,087] Trial 445 pruned.
# [I 2025-02-25 17:01:55,422] Trial 446 pruned.
# [I 2025-02-25 17:01:55,483] Trial 447 pruned.
# [I 2025-02-25 17:01:55,572] Trial 448 pruned.
# [I 2025-02-25 17:01:56,163] Trial 449 pruned.
# [I 2025-02-25 17:01:56,264] Trial 450 pruned.
# [I 2025-02-25 17:01:57,964] Trial 451 pruned.
# [I 2025-02-25 17:01:58,037] Trial 452 pruned.
# [I 2025-02-25 17:01:58,097] Trial 453 pruned.
# [I 2025-02-25 17:01:58,205] Trial 454 pruned.
# [I 2025-02-25 17:01:58,410] Trial 455 pruned.
# [I 2025-02-25 17:01:58,511] Trial 456 pruned.
# [I 2025-02-25 17:01:58,569] Trial 457 pruned.
# [I 2025-02-25 17:01:58,668] Trial 458 pruned.
# [I 2025-02-25 17:01:58,751] Trial 459 pruned.
# [I 2025-02-25 17:01:58,923] Trial 460 pruned.
# [I 2025-02-25 17:01:59,024] Trial 461 pruned.
# [I 2025-02-25 17:01:59,100] Trial 462 pruned.
# [I 2025-02-25 17:01:59,876] Trial 463 pruned.
# [I 2025-02-25 17:02:01,840] Trial 464 finished with value: 0.025862795187143017 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 2700}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:02:01,904] Trial 465 pruned.
# [I 2025-02-25 17:02:02,367] Trial 466 pruned.
# [I 2025-02-25 17:02:02,515] Trial 467 pruned.
# [I 2025-02-25 17:02:02,602] Trial 468 pruned.
# [I 2025-02-25 17:02:02,695] Trial 469 pruned.
# [I 2025-02-25 17:02:02,771] Trial 470 pruned.
# [I 2025-02-25 17:02:03,401] Trial 471 pruned.
# [I 2025-02-25 17:02:05,177] Trial 472 finished with value: 0.03797820559042009 and parameters: {'num_layers': 1, 'dropout_rate': 0.1, 'hidden_size_0': 1600}. Best is trial 2 with value: 0.011522357182911969.
# [I 2025-02-25 17:02:05,300] Trial 473 pruned.
# [I 2025-02-25 17:02:05,370] Trial 474 pruned.
# [I 2025-02-25 17:02:05,481] Trial 475 pruned.
# [I 2025-02-25 17:02:06,071] Trial 476 pruned.
# [I 2025-02-25 17:02:06,141] Trial 477 pruned.
# [I 2025-02-25 17:02:06,213] Trial 478 pruned.
# [I 2025-02-25 17:02:06,289] Trial 479 pruned.
# [I 2025-02-25 17:02:06,355] Trial 480 pruned.
# [I 2025-02-25 17:02:06,918] Trial 481 pruned.
# [I 2025-02-25 17:02:06,994] Trial 482 pruned.
# [I 2025-02-25 17:02:07,258] Trial 483 pruned.
# [I 2025-02-25 17:02:07,344] Trial 484 pruned.
# [I 2025-02-25 17:02:07,456] Trial 485 pruned.
# [I 2025-02-25 17:02:07,615] Trial 486 pruned.
# [I 2025-02-25 17:02:08,038] Trial 487 pruned.
# [I 2025-02-25 17:02:08,101] Trial 488 pruned.
# [I 2025-02-25 17:02:08,820] Trial 489 pruned.
# [I 2025-02-25 17:02:08,887] Trial 490 pruned.
# [I 2025-02-25 17:02:08,972] Trial 491 pruned.
# [I 2025-02-25 17:02:09,036] Trial 492 pruned.
# [I 2025-02-25 17:02:09,119] Trial 493 pruned.
# [I 2025-02-25 17:02:10,646] Trial 494 pruned.
# [I 2025-02-25 17:02:10,746] Trial 495 pruned.
# [I 2025-02-25 17:02:10,855] Trial 496 pruned.
# [I 2025-02-25 17:02:10,989] Trial 497 pruned.
# [I 2025-02-25 17:02:11,384] Trial 498 pruned.
# [I 2025-02-25 17:02:11,449] Trial 499 pruned.
# Stage 2 (Architecture search) Best trial:
#   num_layers: 1
#   dropout_rate: 0.0
#   hidden_size_0: 4140
# Final best configuration:
#   lr: 0.008953359354560458
#   batch_size: 32
#   step_size: 20
#   gamma: 0.8284944216939796
#   num_layers: 1
#   dropout_rate: 0.0
#   hidden_size_0: 4140
